# %% [markdown]
# ## Study effect of less training data

# %%
nlines = 5 #How many lines of data to use for training?
nltest = 60 #How many lines for the test set?

# %%
## Choose GPUs and CPUs

import os
os.environ["CUDA_VISIBLE_DEVICES"]="1"


import tensorflow as tf
import keras
from keras import backend as K
from keras.datasets import mnist

from keras.layers import Conv2D, MaxPool2D
from keras.models import Sequential
from keras.utils import to_categorical, multi_gpu_model, plot_model
from keras.layers import Input, Dense, Conv2D, MaxPooling2D, UpSampling2D, Dropout
from keras.models import Model

GPU=True
CPU=False
num_cores = 32

if GPU:
    num_GPU = len(os.environ["CUDA_VISIBLE_DEVICES"].split(','))
    num_CPU = 4
if CPU:
    num_CPU = 4
    num_GPU = 0

config = tf.ConfigProto(#intra_op_parallelism_threads=num_cores,\
#        inter_op_parallelism_threads=num_cores, 
#        allow_soft_placement=True,\
#        device_count = {'CPU' : num_CPU, 'GPU' : num_GPU},\
#        gpu_options=tf.GPUOptions(per_process_gpu_memory_fraction=0.5))
                       )
config.gpu_options.allow_growth=True 
session = tf.Session(config=config)
K.set_session(session)
# Out:
# Using TensorFlow backend.

# %%
import matplotlib.pyplot as plt
import numpy as np
import glob
from tqdm import tqdm_notebook as tqdm
# Config the matplotlib backend as plotting inline in IPython
# %matplotlib inline

import keras_helper
from keras_helper import *
from skimage.transform import resize

# %%
h,w=64,64
nepochs=75
wt_path = 'wts5'
batch_size = 32

if (not os.path.isdir(wt_path)):
    os.mkdir(wt_path)

# %% [markdown]
# ### Read training data

# %%
np.load('data/20191008_39_diff.npz')['arr_0']

# %%
print(data_diffr.shape)
plt.matshow(np.log10(data_diffr[0,0]))

data_diffr_red = np.zeros((data_diffr.shape[0],data_diffr.shape[1],64,64), float)
for i in tqdm(range(data_diffr.shape[0])):
    for j in range(data_diffr.shape[1]):
        data_diffr_red[i,j] = resize(data_diffr[i,j,32:-32,32:-32],(64,64),preserve_range=True, anti_aliasing=True)
        data_diffr_red[i,j] = np.where(data_diffr_red[i,j]<3,0,data_diffr_red[i,j])
# Out:
# (161, 161, 256, 256)
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:2: RuntimeWarning: divide by zero encountered in log10
# HBox(children=(IntProgress(value=0, max=161), HTML(value='')))
# WARNING: Logging before flag parsing goes to stderr.
# W0328 00:52:19.123952 140087196075840 font_manager.py:1282] findfont: Font family ['Times New Roman'] not found. Falling back to DejaVu Sans.

# %%
plt.matshow(np.log10(data_diffr[0,0,32:-32,32:-32]))
plt.colorbar()
plt.matshow(np.log10(data_diffr_red[0,0]+1))
plt.colorbar()
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: RuntimeWarning: divide by zero encountered in log10
#   """Entry point for launching an IPython kernel.

# %%
#amp = np.load('../expt_data/s26_data/20191008_30_10nm_amp.npz')['arr_0']
#ph = np.load('../expt_data/s26_data/20191008_39_10nm.npz')['arr_0']
real_space = np.load('../expt_data/s26_data/20191008_39_amp_pha_10nm_full.npy')
amp = np.abs(real_space)
ph = np.angle(real_space)
amp.shape
# Out:
# (161, 161, 64, 64)

# %%
fig,ax = plt.subplots(1,2,figsize=(20,10))
ax[0].imshow(amp[:,:,32,32])
ax[1].imshow(ph[:,:,32,32], vmin=-1.5, vmax=1.5)

# %% [markdown]
# ### Split data and then shuffle

# %%
tst_strt = amp.shape[0]-nltest #Where to index from
print(tst_strt)
# Out:
# 101

# %%
from sklearn.utils import shuffle
from sklearn.model_selection import train_test_split


X_train = data_diffr_red[:nlines,:].reshape(-1,h,w)[:,:,:,np.newaxis]
X_test = data_diffr_red[tst_strt:,tst_strt:].reshape(-1,h,w)[:,:,:,np.newaxis]
Y_I_train = amp[:nlines,:].reshape(-1,h,w)[:,:,:,np.newaxis]
Y_I_test = amp[tst_strt:,tst_strt:].reshape(-1,h,w)[:,:,:,np.newaxis]
Y_phi_train = ph[:nlines,:].reshape(-1,h,w)[:,:,:,np.newaxis]
Y_phi_test = ph[tst_strt:,tst_strt:].reshape(-1,h,w)[:,:,:,np.newaxis]

ntrain = X_train.shape[0]*X_train.shape[1]
ntest = X_test.shape[0]*X_test.shape[1]

print(X_train.shape, X_test.shape)

X_train, Y_I_train, Y_phi_train = shuffle(X_train, Y_I_train, Y_phi_train, random_state=0)
#X_train, X_test, Y_I_train, Y_I_test, Y_phi_train, Y_phi_test = \
#    train_test_split(X_data, Y_I_data, Y_phi_data, test_size=0.05, shuffle=False)


#DO NOT SHUFFLE CAUSE NEED
# Out:
# (805, 64, 64, 1) (3600, 64, 64, 1)

# %% [markdown]
# # Autoencoder-structure predictor

# %%
K.clear_session()
np.random.seed(123)
model=Sequential()

files=glob.glob('%s/*' %wt_path)
for file in files:
    os.remove(file)


input_img = Input(shape=(h, w, 1)) 

x = Conv_Pool_block(input_img,32,w1=3,w2=3,p1=2,p2=2, padding='same', data_format='channels_last')
x = Conv_Pool_block(x,64,w1=3,w2=3,p1=2,p2=2, padding='same', data_format='channels_last')
x = Conv_Pool_block(x,128,w1=3,w2=3,p1=2,p2=2, padding='same', data_format='channels_last')
#Activations are all ReLu

encoded=x

#Decoding arm 1
x1=Conv_Up_block(encoded,128,w1=3,w2=3,p1=2,p2=2,padding='same', data_format='channels_last')
x1=Conv_Up_block(x1,64,w1=3,w2=3,p1=2,p2=2,padding='same', data_format='channels_last')
x1=Conv_Up_block(x1,32,w1=3,w2=3,p1=2,p2=2,padding='same', data_format='channels_last')

decoded1 = Conv2D(1, (3, 3), padding='same')(x1)


#Decoding arm 2
x2=Conv_Up_block(encoded,128,w1=3,w2=3,p1=2,p2=2,padding='same', data_format='channels_last')
x2=Conv_Up_block(x2,64,w1=3,w2=3,p1=2,p2=2,padding='same', data_format='channels_last')
x2=Conv_Up_block(x2,32,w1=3,w2=3,p1=2,p2=2,padding='same', data_format='channels_last')

decoded2 = Conv2D(1, (3, 3), padding='same')(x2)

#Put together
autoencoder = Model(input_img, [decoded1, decoded2])
parallel_model = ModelMGPU(autoencoder, gpus=num_GPU)
parallel_model.compile(optimizer='adam', loss='mean_absolute_error')

print (autoencoder.summary())
#plot_model(autoencoder, to_file='paper_data/str_model.png')
# Out:
# W0328 00:52:24.243887 140087196075840 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:95: The name tf.reset_default_graph is deprecated. Please use tf.compat.v1.reset_default_graph instead.
#
# W0328 00:52:24.245352 140087196075840 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:98: The name tf.placeholder_with_default is deprecated. Please use tf.compat.v1.placeholder_with_default instead.
#
# W0328 00:52:24.249460 140087196075840 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:102: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# W0328 00:52:24.278571 140087196075840 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:517: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# W0328 00:52:24.280900 140087196075840 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4138: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# W0328 00:52:24.309796 140087196075840 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3976: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# W0328 00:52:24.395602 140087196075840 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:2018: The name tf.image.resize_nearest_neighbor is deprecated. Please use tf.compat.v1.image.resize_nearest_neighbor instead.
#
# W0328 00:52:24.572642 140087196075840 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/optimizers.py:790: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 64, 64, 1)    0
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 64, 64, 32)   320         input_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 64, 64, 32)   9248        conv2d_1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 32, 32, 32)   0           conv2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 32, 32, 64)   18496       max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 32, 32, 64)   36928       conv2d_3[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 16, 16, 64)   0           conv2d_4[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 16, 16, 128)  73856       max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 16, 16, 128)  147584      conv2d_5[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, 8, 8, 128)    0           conv2d_6[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 8, 8, 128)    147584      max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 8, 8, 128)    147584      max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 8, 8, 128)    147584      conv2d_7[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 8, 8, 128)    147584      conv2d_14[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_1 (UpSampling2D)  (None, 16, 16, 128)  0           conv2d_8[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_4 (UpSampling2D)  (None, 16, 16, 128)  0           conv2d_15[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 16, 16, 64)   73792       up_sampling2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 16, 16, 64)   73792       up_sampling2d_4[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 16, 16, 64)   36928       conv2d_9[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 16, 16, 64)   36928       conv2d_16[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_2 (UpSampling2D)  (None, 32, 32, 64)   0           conv2d_10[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_5 (UpSampling2D)  (None, 32, 32, 64)   0           conv2d_17[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 32, 32, 32)   18464       up_sampling2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 32, 32, 32)   18464       up_sampling2d_5[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 32, 32, 32)   9248        conv2d_11[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 32, 32, 32)   9248        conv2d_18[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_3 (UpSampling2D)  (None, 64, 64, 32)   0           conv2d_12[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_6 (UpSampling2D)  (None, 64, 64, 32)   0           conv2d_19[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 64, 64, 1)    289         up_sampling2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, 64, 64, 1)    289         up_sampling2d_6[0][0]
# ==================================================================================================
# Total params: 1,154,210
# Trainable params: 1,154,210
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None

# %%
reduce_lr = keras.callbacks.ReduceLROnPlateau(monitor='val_loss', factor=0.5,
                              patience=2, min_lr=0.0001, verbose=1)

checkpoints=keras.callbacks.ModelCheckpoint('%s/weights.{epoch:02d}.hdf5' %wt_path, 
                                            monitor='val_loss', verbose=1, save_best_only=True, 
                                            save_weights_only=False, mode='auto', period=1)

history=parallel_model.fit(X_train, [Y_I_train, Y_phi_train], shuffle=True, batch_size=batch_size, verbose=1, 
                           epochs=nepochs, validation_split = 0.05, callbacks=[checkpoints, reduce_lr])
# Out:
# Train on 764 samples, validate on 41 samples
# Epoch 1/75
# 764/764 [==============================] - 4s 5ms/step - loss: 2.5366 - conv2d_13_loss: 0.6441 - conv2d_20_loss: 1.8925 - val_loss: 0.6993 - val_conv2d_13_loss: 0.0234 - val_conv2d_20_loss: 0.6759
#
# Epoch 00001: val_loss improved from inf to 0.69927, saving model to wts5/weights.01.hdf5
# Epoch 2/75
# 764/764 [==============================] - 1s 779us/step - loss: 0.6534 - conv2d_13_loss: 0.0179 - conv2d_20_loss: 0.6355 - val_loss: 0.6347 - val_conv2d_13_loss: 0.0129 - val_conv2d_20_loss: 0.6218
#
# Epoch 00002: val_loss improved from 0.69927 to 0.63468, saving model to wts5/weights.02.hdf5
# Epoch 3/75
# 764/764 [==============================] - 1s 826us/step - loss: 0.6009 - conv2d_13_loss: 0.0121 - conv2d_20_loss: 0.5888 - val_loss: 0.6135 - val_conv2d_13_loss: 0.0112 - val_conv2d_20_loss: 0.6023
#
# Epoch 00003: val_loss improved from 0.63468 to 0.61348, saving model to wts5/weights.03.hdf5
# Epoch 4/75
# 764/764 [==============================] - 1s 853us/step - loss: 0.5796 - conv2d_13_loss: 0.0105 - conv2d_20_loss: 0.5690 - val_loss: 0.5979 - val_conv2d_13_loss: 0.0099 - val_conv2d_20_loss: 0.5880
#
# Epoch 00004: val_loss improved from 0.61348 to 0.59792, saving model to wts5/weights.04.hdf5
# Epoch 5/75
# 764/764 [==============================] - 1s 860us/step - loss: 0.5512 - conv2d_13_loss: 0.0097 - conv2d_20_loss: 0.5415 - val_loss: 0.5949 - val_conv2d_13_loss: 0.0098 - val_conv2d_20_loss: 0.5850
#
# Epoch 00005: val_loss improved from 0.59792 to 0.59487, saving model to wts5/weights.05.hdf5
# Epoch 6/75
# 764/764 [==============================] - 1s 862us/step - loss: 0.5566 - conv2d_13_loss: 0.0095 - conv2d_20_loss: 0.5471 - val_loss: 0.5659 - val_conv2d_13_loss: 0.0093 - val_conv2d_20_loss: 0.5566
#
# Epoch 00006: val_loss improved from 0.59487 to 0.56594, saving model to wts5/weights.06.hdf5
# Epoch 7/75
# 764/764 [==============================] - 1s 846us/step - loss: 0.5219 - conv2d_13_loss: 0.0093 - conv2d_20_loss: 0.5126 - val_loss: 0.5448 - val_conv2d_13_loss: 0.0093 - val_conv2d_20_loss: 0.5355
#
# Epoch 00007: val_loss improved from 0.56594 to 0.54484, saving model to wts5/weights.07.hdf5
# Epoch 8/75
# 764/764 [==============================] - 1s 829us/step - loss: 0.5024 - conv2d_13_loss: 0.0092 - conv2d_20_loss: 0.4932 - val_loss: 0.5128 - val_conv2d_13_loss: 0.0090 - val_conv2d_20_loss: 0.5038
#
# Epoch 00008: val_loss improved from 0.54484 to 0.51279, saving model to wts5/weights.08.hdf5
# Epoch 9/75
# 764/764 [==============================] - 1s 799us/step - loss: 0.4755 - conv2d_13_loss: 0.0091 - conv2d_20_loss: 0.4664 - val_loss: 0.4841 - val_conv2d_13_loss: 0.0089 - val_conv2d_20_loss: 0.4752
#
# Epoch 00009: val_loss improved from 0.51279 to 0.48409, saving model to wts5/weights.09.hdf5
# Epoch 10/75
# 764/764 [==============================] - 1s 820us/step - loss: 0.4513 - conv2d_13_loss: 0.0091 - conv2d_20_loss: 0.4421 - val_loss: 0.4884 - val_conv2d_13_loss: 0.0090 - val_conv2d_20_loss: 0.4793
#
# Epoch 00010: val_loss did not improve from 0.48409
# Epoch 11/75
# 764/764 [==============================] - 1s 861us/step - loss: 0.4259 - conv2d_13_loss: 0.0090 - conv2d_20_loss: 0.4168 - val_loss: 0.4431 - val_conv2d_13_loss: 0.0089 - val_conv2d_20_loss: 0.4341
#
# Epoch 00011: val_loss improved from 0.48409 to 0.44306, saving model to wts5/weights.11.hdf5
# Epoch 12/75
# 764/764 [==============================] - 1s 938us/step - loss: 0.4054 - conv2d_13_loss: 0.0090 - conv2d_20_loss: 0.3964 - val_loss: 0.4283 - val_conv2d_13_loss: 0.0089 - val_conv2d_20_loss: 0.4194
#
# Epoch 00012: val_loss improved from 0.44306 to 0.42829, saving model to wts5/weights.12.hdf5
# Epoch 13/75
# 764/764 [==============================] - 1s 836us/step - loss: 0.3678 - conv2d_13_loss: 0.0089 - conv2d_20_loss: 0.3589 - val_loss: 0.4007 - val_conv2d_13_loss: 0.0087 - val_conv2d_20_loss: 0.3920
#
# Epoch 00013: val_loss improved from 0.42829 to 0.40073, saving model to wts5/weights.13.hdf5
# Epoch 14/75
# 764/764 [==============================] - 1s 813us/step - loss: 0.3437 - conv2d_13_loss: 0.0088 - conv2d_20_loss: 0.3348 - val_loss: 0.3820 - val_conv2d_13_loss: 0.0087 - val_conv2d_20_loss: 0.3733
#
# Epoch 00014: val_loss improved from 0.40073 to 0.38199, saving model to wts5/weights.14.hdf5
# Epoch 15/75
# 764/764 [==============================] - 1s 827us/step - loss: 0.3347 - conv2d_13_loss: 0.0087 - conv2d_20_loss: 0.3259 - val_loss: 0.3710 - val_conv2d_13_loss: 0.0086 - val_conv2d_20_loss: 0.3624
#
# Epoch 00015: val_loss improved from 0.38199 to 0.37098, saving model to wts5/weights.15.hdf5
# Epoch 16/75
# 764/764 [==============================] - 1s 830us/step - loss: 0.3058 - conv2d_13_loss: 0.0087 - conv2d_20_loss: 0.2972 - val_loss: 0.3521 - val_conv2d_13_loss: 0.0086 - val_conv2d_20_loss: 0.3435
#
# Epoch 00016: val_loss improved from 0.37098 to 0.35214, saving model to wts5/weights.16.hdf5
# Epoch 17/75
# 764/764 [==============================] - 1s 871us/step - loss: 0.2938 - conv2d_13_loss: 0.0086 - conv2d_20_loss: 0.2852 - val_loss: 0.3281 - val_conv2d_13_loss: 0.0085 - val_conv2d_20_loss: 0.3196
#
# Epoch 00017: val_loss improved from 0.35214 to 0.32807, saving model to wts5/weights.17.hdf5
# Epoch 18/75
# 764/764 [==============================] - 1s 822us/step - loss: 0.2759 - conv2d_13_loss: 0.0085 - conv2d_20_loss: 0.2675 - val_loss: 0.3056 - val_conv2d_13_loss: 0.0085 - val_conv2d_20_loss: 0.2971
#
# Epoch 00018: val_loss improved from 0.32807 to 0.30561, saving model to wts5/weights.18.hdf5
# Epoch 19/75
# 764/764 [==============================] - 1s 801us/step - loss: 0.2558 - conv2d_13_loss: 0.0084 - conv2d_20_loss: 0.2474 - val_loss: 0.2958 - val_conv2d_13_loss: 0.0084 - val_conv2d_20_loss: 0.2874
#
# Epoch 00019: val_loss improved from 0.30561 to 0.29580, saving model to wts5/weights.19.hdf5
# Epoch 20/75
# 764/764 [==============================] - 1s 830us/step - loss: 0.2392 - conv2d_13_loss: 0.0083 - conv2d_20_loss: 0.2310 - val_loss: 0.2889 - val_conv2d_13_loss: 0.0083 - val_conv2d_20_loss: 0.2806
#
# Epoch 00020: val_loss improved from 0.29580 to 0.28887, saving model to wts5/weights.20.hdf5
# Epoch 21/75
# 764/764 [==============================] - 1s 808us/step - loss: 0.2302 - conv2d_13_loss: 0.0082 - conv2d_20_loss: 0.2220 - val_loss: 0.2976 - val_conv2d_13_loss: 0.0082 - val_conv2d_20_loss: 0.2895
#
# Epoch 00021: val_loss did not improve from 0.28887
# Epoch 22/75
# 764/764 [==============================] - 1s 838us/step - loss: 0.2299 - conv2d_13_loss: 0.0081 - conv2d_20_loss: 0.2218 - val_loss: 0.2658 - val_conv2d_13_loss: 0.0082 - val_conv2d_20_loss: 0.2577
#
# Epoch 00022: val_loss improved from 0.28887 to 0.26582, saving model to wts5/weights.22.hdf5
# Epoch 23/75
# 764/764 [==============================] - 1s 827us/step - loss: 0.2181 - conv2d_13_loss: 0.0080 - conv2d_20_loss: 0.2101 - val_loss: 0.2650 - val_conv2d_13_loss: 0.0081 - val_conv2d_20_loss: 0.2569
#
# Epoch 00023: val_loss improved from 0.26582 to 0.26495, saving model to wts5/weights.23.hdf5
# Epoch 24/75
# 764/764 [==============================] - 1s 805us/step - loss: 0.2073 - conv2d_13_loss: 0.0079 - conv2d_20_loss: 0.1994 - val_loss: 0.2530 - val_conv2d_13_loss: 0.0080 - val_conv2d_20_loss: 0.2450
#
# Epoch 00024: val_loss improved from 0.26495 to 0.25297, saving model to wts5/weights.24.hdf5
# Epoch 25/75
# 764/764 [==============================] - 1s 848us/step - loss: 0.1955 - conv2d_13_loss: 0.0078 - conv2d_20_loss: 0.1877 - val_loss: 0.2408 - val_conv2d_13_loss: 0.0078 - val_conv2d_20_loss: 0.2330
#
# Epoch 00025: val_loss improved from 0.25297 to 0.24084, saving model to wts5/weights.25.hdf5
# Epoch 26/75
# 764/764 [==============================] - 1s 905us/step - loss: 0.1919 - conv2d_13_loss: 0.0077 - conv2d_20_loss: 0.1843 - val_loss: 0.2391 - val_conv2d_13_loss: 0.0078 - val_conv2d_20_loss: 0.2313
#
# Epoch 00026: val_loss improved from 0.24084 to 0.23913, saving model to wts5/weights.26.hdf5
# Epoch 27/75
# 764/764 [==============================] - 1s 819us/step - loss: 0.1818 - conv2d_13_loss: 0.0075 - conv2d_20_loss: 0.1742 - val_loss: 0.2358 - val_conv2d_13_loss: 0.0077 - val_conv2d_20_loss: 0.2281
#
# Epoch 00027: val_loss improved from 0.23913 to 0.23580, saving model to wts5/weights.27.hdf5
# Epoch 28/75
# 764/764 [==============================] - 1s 768us/step - loss: 0.1793 - conv2d_13_loss: 0.0075 - conv2d_20_loss: 0.1719 - val_loss: 0.2367 - val_conv2d_13_loss: 0.0077 - val_conv2d_20_loss: 0.2290
#
# Epoch 00028: val_loss did not improve from 0.23580
# Epoch 29/75
# 764/764 [==============================] - 1s 861us/step - loss: 0.1711 - conv2d_13_loss: 0.0074 - conv2d_20_loss: 0.1637 - val_loss: 0.2184 - val_conv2d_13_loss: 0.0075 - val_conv2d_20_loss: 0.2109
#
# Epoch 00029: val_loss improved from 0.23580 to 0.21843, saving model to wts5/weights.29.hdf5
# Epoch 30/75
# 764/764 [==============================] - 1s 806us/step - loss: 0.1688 - conv2d_13_loss: 0.0073 - conv2d_20_loss: 0.1615 - val_loss: 0.2202 - val_conv2d_13_loss: 0.0074 - val_conv2d_20_loss: 0.2128
#
# Epoch 00030: val_loss did not improve from 0.21843
# Epoch 31/75
# 764/764 [==============================] - 1s 818us/step - loss: 0.1607 - conv2d_13_loss: 0.0072 - conv2d_20_loss: 0.1536 - val_loss: 0.2187 - val_conv2d_13_loss: 0.0075 - val_conv2d_20_loss: 0.2112
#
# Epoch 00031: val_loss did not improve from 0.21843
#
# Epoch 00031: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# Epoch 32/75
# 764/764 [==============================] - 1s 811us/step - loss: 0.1459 - conv2d_13_loss: 0.0071 - conv2d_20_loss: 0.1388 - val_loss: 0.1986 - val_conv2d_13_loss: 0.0073 - val_conv2d_20_loss: 0.1913
#
# Epoch 00032: val_loss improved from 0.21843 to 0.19857, saving model to wts5/weights.32.hdf5
# Epoch 33/75
# 764/764 [==============================] - 1s 756us/step - loss: 0.1331 - conv2d_13_loss: 0.0070 - conv2d_20_loss: 0.1261 - val_loss: 0.1845 - val_conv2d_13_loss: 0.0073 - val_conv2d_20_loss: 0.1773
#
# Epoch 00033: val_loss improved from 0.19857 to 0.18451, saving model to wts5/weights.33.hdf5
# Epoch 34/75
# 764/764 [==============================] - 1s 812us/step - loss: 0.1268 - conv2d_13_loss: 0.0069 - conv2d_20_loss: 0.1199 - val_loss: 0.1847 - val_conv2d_13_loss: 0.0072 - val_conv2d_20_loss: 0.1775
#
# Epoch 00034: val_loss did not improve from 0.18451
# Epoch 35/75
# 764/764 [==============================] - 1s 815us/step - loss: 0.1245 - conv2d_13_loss: 0.0069 - conv2d_20_loss: 0.1176 - val_loss: 0.1817 - val_conv2d_13_loss: 0.0072 - val_conv2d_20_loss: 0.1745
#
# Epoch 00035: val_loss improved from 0.18451 to 0.18165, saving model to wts5/weights.35.hdf5
# Epoch 36/75
# 764/764 [==============================] - 1s 825us/step - loss: 0.1219 - conv2d_13_loss: 0.0069 - conv2d_20_loss: 0.1151 - val_loss: 0.1794 - val_conv2d_13_loss: 0.0071 - val_conv2d_20_loss: 0.1722
#
# Epoch 00036: val_loss improved from 0.18165 to 0.17939, saving model to wts5/weights.36.hdf5
# Epoch 37/75
# 764/764 [==============================] - 1s 726us/step - loss: 0.1210 - conv2d_13_loss: 0.0068 - conv2d_20_loss: 0.1142 - val_loss: 0.1865 - val_conv2d_13_loss: 0.0071 - val_conv2d_20_loss: 0.1794
#
# Epoch 00037: val_loss did not improve from 0.17939
# Epoch 38/75
# 764/764 [==============================] - 1s 830us/step - loss: 0.1196 - conv2d_13_loss: 0.0068 - conv2d_20_loss: 0.1128 - val_loss: 0.1790 - val_conv2d_13_loss: 0.0071 - val_conv2d_20_loss: 0.1719
#
# Epoch 00038: val_loss improved from 0.17939 to 0.17904, saving model to wts5/weights.38.hdf5
# Epoch 39/75
# 764/764 [==============================] - 1s 762us/step - loss: 0.1157 - conv2d_13_loss: 0.0068 - conv2d_20_loss: 0.1090 - val_loss: 0.1784 - val_conv2d_13_loss: 0.0070 - val_conv2d_20_loss: 0.1714
#
# Epoch 00039: val_loss improved from 0.17904 to 0.17841, saving model to wts5/weights.39.hdf5
# Epoch 40/75
# 764/764 [==============================] - 1s 747us/step - loss: 0.1135 - conv2d_13_loss: 0.0067 - conv2d_20_loss: 0.1067 - val_loss: 0.1755 - val_conv2d_13_loss: 0.0070 - val_conv2d_20_loss: 0.1685
#
# Epoch 00040: val_loss improved from 0.17841 to 0.17552, saving model to wts5/weights.40.hdf5
# Epoch 41/75
# 764/764 [==============================] - 1s 741us/step - loss: 0.1117 - conv2d_13_loss: 0.0067 - conv2d_20_loss: 0.1050 - val_loss: 0.1758 - val_conv2d_13_loss: 0.0070 - val_conv2d_20_loss: 0.1688
#
# Epoch 00041: val_loss did not improve from 0.17552
# Epoch 42/75
# 764/764 [==============================] - 1s 780us/step - loss: 0.1107 - conv2d_13_loss: 0.0067 - conv2d_20_loss: 0.1040 - val_loss: 0.1733 - val_conv2d_13_loss: 0.0070 - val_conv2d_20_loss: 0.1663
#
# Epoch 00042: val_loss improved from 0.17552 to 0.17332, saving model to wts5/weights.42.hdf5
# Epoch 43/75
# 764/764 [==============================] - 1s 752us/step - loss: 0.1112 - conv2d_13_loss: 0.0066 - conv2d_20_loss: 0.1045 - val_loss: 0.1715 - val_conv2d_13_loss: 0.0070 - val_conv2d_20_loss: 0.1645
#
# Epoch 00043: val_loss improved from 0.17332 to 0.17148, saving model to wts5/weights.43.hdf5
# Epoch 44/75
# 764/764 [==============================] - 1s 751us/step - loss: 0.1107 - conv2d_13_loss: 0.0066 - conv2d_20_loss: 0.1041 - val_loss: 0.1745 - val_conv2d_13_loss: 0.0069 - val_conv2d_20_loss: 0.1676
#
# Epoch 00044: val_loss did not improve from 0.17148
# Epoch 45/75
# 764/764 [==============================] - 1s 760us/step - loss: 0.1093 - conv2d_13_loss: 0.0066 - conv2d_20_loss: 0.1027 - val_loss: 0.1685 - val_conv2d_13_loss: 0.0069 - val_conv2d_20_loss: 0.1615
#
# Epoch 00045: val_loss improved from 0.17148 to 0.16848, saving model to wts5/weights.45.hdf5
# Epoch 46/75
# 764/764 [==============================] - 1s 760us/step - loss: 0.1087 - conv2d_13_loss: 0.0066 - conv2d_20_loss: 0.1022 - val_loss: 0.1703 - val_conv2d_13_loss: 0.0069 - val_conv2d_20_loss: 0.1635
#
# Epoch 00046: val_loss did not improve from 0.16848
# Epoch 47/75
# 764/764 [==============================] - 1s 728us/step - loss: 0.1078 - conv2d_13_loss: 0.0065 - conv2d_20_loss: 0.1012 - val_loss: 0.1692 - val_conv2d_13_loss: 0.0069 - val_conv2d_20_loss: 0.1623
#
# Epoch 00047: val_loss did not improve from 0.16848
#
# Epoch 00047: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# Epoch 48/75
# 764/764 [==============================] - 1s 738us/step - loss: 0.1010 - conv2d_13_loss: 0.0065 - conv2d_20_loss: 0.0945 - val_loss: 0.1648 - val_conv2d_13_loss: 0.0069 - val_conv2d_20_loss: 0.1579
#
# Epoch 00048: val_loss improved from 0.16848 to 0.16476, saving model to wts5/weights.48.hdf5
# Epoch 49/75
# 764/764 [==============================] - 1s 721us/step - loss: 0.0961 - conv2d_13_loss: 0.0065 - conv2d_20_loss: 0.0897 - val_loss: 0.1643 - val_conv2d_13_loss: 0.0068 - val_conv2d_20_loss: 0.1575
#
# Epoch 00049: val_loss improved from 0.16476 to 0.16429, saving model to wts5/weights.49.hdf5
# Epoch 50/75
# 764/764 [==============================] - 1s 716us/step - loss: 0.0941 - conv2d_13_loss: 0.0065 - conv2d_20_loss: 0.0876 - val_loss: 0.1627 - val_conv2d_13_loss: 0.0068 - val_conv2d_20_loss: 0.1558
#
# Epoch 00050: val_loss improved from 0.16429 to 0.16266, saving model to wts5/weights.50.hdf5
# Epoch 51/75
# 764/764 [==============================] - 1s 700us/step - loss: 0.0920 - conv2d_13_loss: 0.0064 - conv2d_20_loss: 0.0856 - val_loss: 0.1622 - val_conv2d_13_loss: 0.0068 - val_conv2d_20_loss: 0.1553
#
# Epoch 00051: val_loss improved from 0.16266 to 0.16218, saving model to wts5/weights.51.hdf5
# Epoch 52/75
# 764/764 [==============================] - 1s 695us/step - loss: 0.0906 - conv2d_13_loss: 0.0064 - conv2d_20_loss: 0.0842 - val_loss: 0.1612 - val_conv2d_13_loss: 0.0068 - val_conv2d_20_loss: 0.1544
#
# Epoch 00052: val_loss improved from 0.16218 to 0.16118, saving model to wts5/weights.52.hdf5
# Epoch 53/75
# 764/764 [==============================] - 1s 769us/step - loss: 0.0898 - conv2d_13_loss: 0.0064 - conv2d_20_loss: 0.0834 - val_loss: 0.1615 - val_conv2d_13_loss: 0.0068 - val_conv2d_20_loss: 0.1547
#
# Epoch 00053: val_loss did not improve from 0.16118
# Epoch 54/75
# 764/764 [==============================] - 1s 751us/step - loss: 0.0894 - conv2d_13_loss: 0.0064 - conv2d_20_loss: 0.0830 - val_loss: 0.1606 - val_conv2d_13_loss: 0.0068 - val_conv2d_20_loss: 0.1537
#
# Epoch 00054: val_loss improved from 0.16118 to 0.16056, saving model to wts5/weights.54.hdf5
# Epoch 55/75
# 764/764 [==============================] - 1s 780us/step - loss: 0.0886 - conv2d_13_loss: 0.0064 - conv2d_20_loss: 0.0823 - val_loss: 0.1599 - val_conv2d_13_loss: 0.0068 - val_conv2d_20_loss: 0.1531
#
# Epoch 00055: val_loss improved from 0.16056 to 0.15988, saving model to wts5/weights.55.hdf5
# Epoch 56/75
# 764/764 [==============================] - 1s 763us/step - loss: 0.0881 - conv2d_13_loss: 0.0064 - conv2d_20_loss: 0.0818 - val_loss: 0.1609 - val_conv2d_13_loss: 0.0068 - val_conv2d_20_loss: 0.1541
#
# Epoch 00056: val_loss did not improve from 0.15988
# Epoch 57/75
# 764/764 [==============================] - 1s 822us/step - loss: 0.0879 - conv2d_13_loss: 0.0064 - conv2d_20_loss: 0.0815 - val_loss: 0.1608 - val_conv2d_13_loss: 0.0068 - val_conv2d_20_loss: 0.1541
#
# Epoch 00057: val_loss did not improve from 0.15988
#
# Epoch 00057: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# Epoch 58/75
# 764/764 [==============================] - 1s 818us/step - loss: 0.0860 - conv2d_13_loss: 0.0063 - conv2d_20_loss: 0.0797 - val_loss: 0.1593 - val_conv2d_13_loss: 0.0068 - val_conv2d_20_loss: 0.1525
#
# Epoch 00058: val_loss improved from 0.15988 to 0.15927, saving model to wts5/weights.58.hdf5
# Epoch 59/75
# 764/764 [==============================] - 1s 739us/step - loss: 0.0846 - conv2d_13_loss: 0.0063 - conv2d_20_loss: 0.0782 - val_loss: 0.1587 - val_conv2d_13_loss: 0.0068 - val_conv2d_20_loss: 0.1519
#
# Epoch 00059: val_loss improved from 0.15927 to 0.15869, saving model to wts5/weights.59.hdf5
# Epoch 60/75
# 764/764 [==============================] - 1s 741us/step - loss: 0.0838 - conv2d_13_loss: 0.0063 - conv2d_20_loss: 0.0774 - val_loss: 0.1583 - val_conv2d_13_loss: 0.0068 - val_conv2d_20_loss: 0.1516
#
# Epoch 00060: val_loss improved from 0.15869 to 0.15832, saving model to wts5/weights.60.hdf5
# Epoch 61/75
# 764/764 [==============================] - 1s 774us/step - loss: 0.0833 - conv2d_13_loss: 0.0063 - conv2d_20_loss: 0.0770 - val_loss: 0.1584 - val_conv2d_13_loss: 0.0068 - val_conv2d_20_loss: 0.1517
#
# Epoch 00061: val_loss did not improve from 0.15832
# Epoch 62/75
# 764/764 [==============================] - 1s 768us/step - loss: 0.0828 - conv2d_13_loss: 0.0063 - conv2d_20_loss: 0.0765 - val_loss: 0.1584 - val_conv2d_13_loss: 0.0068 - val_conv2d_20_loss: 0.1516
#
# Epoch 00062: val_loss did not improve from 0.15832
#
# Epoch 00062: ReduceLROnPlateau reducing learning rate to 0.0001.
# Epoch 63/75
# 764/764 [==============================] - 1s 702us/step - loss: 0.0824 - conv2d_13_loss: 0.0063 - conv2d_20_loss: 0.0761 - val_loss: 0.1586 - val_conv2d_13_loss: 0.0068 - val_conv2d_20_loss: 0.1519
#
# Epoch 00063: val_loss did not improve from 0.15832
# Epoch 64/75
# 764/764 [==============================] - 1s 722us/step - loss: 0.0821 - conv2d_13_loss: 0.0063 - conv2d_20_loss: 0.0758 - val_loss: 0.1584 - val_conv2d_13_loss: 0.0068 - val_conv2d_20_loss: 0.1516
#
# Epoch 00064: val_loss did not improve from 0.15832
# Epoch 65/75
# 764/764 [==============================] - 1s 733us/step - loss: 0.0817 - conv2d_13_loss: 0.0063 - conv2d_20_loss: 0.0754 - val_loss: 0.1580 - val_conv2d_13_loss: 0.0067 - val_conv2d_20_loss: 0.1513
#
# Epoch 00065: val_loss improved from 0.15832 to 0.15802, saving model to wts5/weights.65.hdf5
# Epoch 66/75
# 764/764 [==============================] - 1s 792us/step - loss: 0.0815 - conv2d_13_loss: 0.0063 - conv2d_20_loss: 0.0752 - val_loss: 0.1573 - val_conv2d_13_loss: 0.0067 - val_conv2d_20_loss: 0.1505
#
# Epoch 00066: val_loss improved from 0.15802 to 0.15727, saving model to wts5/weights.66.hdf5
# Epoch 67/75
# 764/764 [==============================] - 1s 745us/step - loss: 0.0812 - conv2d_13_loss: 0.0063 - conv2d_20_loss: 0.0749 - val_loss: 0.1577 - val_conv2d_13_loss: 0.0067 - val_conv2d_20_loss: 0.1510
#
# Epoch 00067: val_loss did not improve from 0.15727
# Epoch 68/75
# 764/764 [==============================] - 1s 813us/step - loss: 0.0810 - conv2d_13_loss: 0.0063 - conv2d_20_loss: 0.0747 - val_loss: 0.1574 - val_conv2d_13_loss: 0.0067 - val_conv2d_20_loss: 0.1507
#
# Epoch 00068: val_loss did not improve from 0.15727
# Epoch 69/75
# 764/764 [==============================] - 1s 769us/step - loss: 0.0807 - conv2d_13_loss: 0.0063 - conv2d_20_loss: 0.0744 - val_loss: 0.1572 - val_conv2d_13_loss: 0.0067 - val_conv2d_20_loss: 0.1504
#
# Epoch 00069: val_loss improved from 0.15727 to 0.15717, saving model to wts5/weights.69.hdf5
# Epoch 70/75
# 764/764 [==============================] - 1s 735us/step - loss: 0.0805 - conv2d_13_loss: 0.0063 - conv2d_20_loss: 0.0742 - val_loss: 0.1571 - val_conv2d_13_loss: 0.0067 - val_conv2d_20_loss: 0.1504
#
# Epoch 00070: val_loss improved from 0.15717 to 0.15714, saving model to wts5/weights.70.hdf5
# Epoch 71/75
# 764/764 [==============================] - 1s 742us/step - loss: 0.0802 - conv2d_13_loss: 0.0063 - conv2d_20_loss: 0.0740 - val_loss: 0.1574 - val_conv2d_13_loss: 0.0067 - val_conv2d_20_loss: 0.1506
#
# Epoch 00071: val_loss did not improve from 0.15714
# Epoch 72/75
# 764/764 [==============================] - 1s 770us/step - loss: 0.0800 - conv2d_13_loss: 0.0063 - conv2d_20_loss: 0.0737 - val_loss: 0.1572 - val_conv2d_13_loss: 0.0067 - val_conv2d_20_loss: 0.1505
#
# Epoch 00072: val_loss did not improve from 0.15714
# Epoch 73/75
# 764/764 [==============================] - 1s 753us/step - loss: 0.0798 - conv2d_13_loss: 0.0063 - conv2d_20_loss: 0.0735 - val_loss: 0.1568 - val_conv2d_13_loss: 0.0067 - val_conv2d_20_loss: 0.1501
#
# Epoch 00073: val_loss improved from 0.15714 to 0.15682, saving model to wts5/weights.73.hdf5
# Epoch 74/75
# 764/764 [==============================] - 1s 742us/step - loss: 0.0796 - conv2d_13_loss: 0.0062 - conv2d_20_loss: 0.0734 - val_loss: 0.1572 - val_conv2d_13_loss: 0.0067 - val_conv2d_20_loss: 0.1505
#
# Epoch 00074: val_loss did not improve from 0.15682
# Epoch 75/75
# 764/764 [==============================] - 1s 739us/step - loss: 0.0794 - conv2d_13_loss: 0.0062 - conv2d_20_loss: 0.0731 - val_loss: 0.1562 - val_conv2d_13_loss: 0.0067 - val_conv2d_20_loss: 0.1495
#
# Epoch 00075: val_loss improved from 0.15682 to 0.15620, saving model to wts5/weights.75.hdf5

# %%
hist=history
epochs=np.asarray(history.epoch)+1

# %matplotlib inline
import matplotlib
plt.style.use('seaborn-white')
matplotlib.rc('font',family='Times New Roman')
matplotlib.rcParams['font.size'] = 20

f, axarr = plt.subplots(3, sharex=True, figsize=(12, 8))

axarr[0].set(ylabel='Loss')
axarr[0].plot(epochs,hist.history['loss'], 'C3o', label='Total Training')
axarr[0].plot(epochs,hist.history['val_loss'], 'C3-', label='Total Validation')
axarr[0].grid()
axarr[0].legend(loc='center right', bbox_to_anchor=(1.5, 0.5))

axarr[1].set(ylabel='Loss')
axarr[1].plot(epochs,hist.history['conv2d_13_loss'], 'C0o', label='Structure Training')
axarr[1].plot(epochs,hist.history['val_conv2d_13_loss'], 'C0-', label='Structure Validation')
axarr[1].legend(loc='center right', bbox_to_anchor=(1.5, 0.5))
plt.xlabel('Epochs')
plt.tight_layout()
axarr[1].grid()


axarr[2].set(ylabel='Loss')
axarr[2].plot(epochs,hist.history['conv2d_20_loss'], 'C0o', label='Phase Training')
axarr[2].plot(epochs,hist.history['val_conv2d_20_loss'], 'C0-', label='Phase Validation')
axarr[2].legend(loc='center right', bbox_to_anchor=(1.5, 0.5))
plt.tight_layout()
axarr[2].grid()
# Out:
# W0328 00:53:19.414415 140087196075840 font_manager.py:1282] findfont: Font family ['Times New Roman'] not found. Falling back to DejaVu Sans.

# %%
#np.save('paper_data/str_history', history.history)

# %%
val_losses=hist.history['val_loss']
min_epoch=np.argmin(val_losses)+1
print (min_epoch)
np.save('%s/min_epoch' %(wt_path), min_epoch)
# Out:
# 75

# %%
min_epoch = np.load('%s/min_epoch.npy' %wt_path)
from keras.models import Model, load_model
model=load_model('%s/weights.%02d.hdf5' %(wt_path,min_epoch))
#score=model.evaluate(ft_test, test_dataset, verbose=1)
#print (score)
# Out:
# /usr/local/lib/python3.6/dist-packages/keras/engine/saving.py:292: UserWarning: No training configuration found in save file: the model was *not* compiled. Compile it manually.
#   warnings.warn('No training configuration found in save file: '

# %%
preds_intens=(model.predict(X_test))
print (preds_intens[0].shape)
# Out:
# (3600, 64, 64, 1)

# %%
#preds_intens=np.where(preds_intens<0.1,0,preds_intens)

# %% [markdown]
# # Plot some instances of the test data, it's FT and the CNN prediction

# %%
ntest=preds_intens[0].shape[0]
plt.viridis()
n = 5
f,ax=plt.subplots(5,n,figsize=(20, 12))
plt.gcf().text(0.02, 0.8, "Input", fontsize=20)
plt.gcf().text(0.02, 0.65, "True I", fontsize=20)
plt.gcf().text(0.02, 0.5, "Predicted I", fontsize=20)
plt.gcf().text(0.02, 0.35, "True Phi", fontsize=20)
plt.gcf().text(0.02, 0.2, "Predicted Phi", fontsize=20)

for i in range(0,n):
    j=int(round(np.random.rand()*ntest))

        # display FT
    im=ax[0,i].imshow(np.log10(X_test[j].reshape(h, w)+1))
    plt.colorbar(im, ax=ax[0,i])
    ax[0,i].get_xaxis().set_visible(False)
    ax[0,i].get_yaxis().set_visible(False)

    # display original intens
    im=ax[1,i].imshow(Y_I_test[j].reshape(h, w))
    plt.colorbar(im, ax=ax[1,i])
    ax[1,i].get_xaxis().set_visible(False)
    ax[1,i].get_yaxis().set_visible(False)
    
    # display predicted intens
    im=ax[2,i].imshow(preds_intens[0][j].reshape(h, w))
    plt.colorbar(im, ax=ax[2,i])
    ax[2,i].get_xaxis().set_visible(False)
    ax[2,i].get_yaxis().set_visible(False)
    
        # display original phase
    im=ax[3,i].imshow(Y_phi_test[j].reshape(h, w))
    plt.colorbar(im, ax=ax[3,i])
    ax[3,i].get_xaxis().set_visible(False)
    ax[3,i].get_yaxis().set_visible(False)
    
    # display predicted phase
    im=ax[4,i].imshow(preds_intens[1][j].reshape(h, w))
    plt.colorbar(im, ax=ax[4,i])
    ax[4,i].get_xaxis().set_visible(False)
    ax[4,i].get_yaxis().set_visible(False)
    
plt.show()

# %%
j=10
fig, ax = plt.subplots(1,3,figsize=(12,6))
ax[0].imshow(np.log10(X_test[j].reshape(h, w)+1))
ax[1].imshow(preds_intens[0][j].reshape(h, w))
ax[2].imshow(preds_intens[1][j].reshape(h, w))

# %% [markdown]
# ## Plot NN predictions

# %%
tst_side = nltest
tst_side
# Out:
# 60

# %%
fig, ax = plt.subplots(3,3, figsize=(12,6))
ax[0,0].imshow((preds_intens[1].reshape(tst_side,tst_side,64,64)[9,9]))
ax[0,1].imshow((preds_intens[1].reshape(tst_side,tst_side,64,64)[9,10]))
ax[0,2].imshow((preds_intens[1].reshape(tst_side,tst_side,64,64)[9,11]))
ax[1,0].imshow((preds_intens[1].reshape(tst_side,tst_side,64,64)[10,9]))
ax[1,1].imshow((preds_intens[1].reshape(tst_side,tst_side,64,64)[10,10]))
ax[1,2].imshow((preds_intens[1].reshape(tst_side,tst_side,64,64)[10,11]))
ax[2,0].imshow((preds_intens[1].reshape(tst_side,tst_side,64,64)[11,9]))
ax[2,1].imshow((preds_intens[1].reshape(tst_side,tst_side,64,64)[11,10]))
ax[2,2].imshow((preds_intens[1].reshape(tst_side,tst_side,64,64)[11,11]))

# %%
point_size = 3
overlap = 4*point_size

# %%
composite_phase = np.zeros((tst_side*point_size+overlap,tst_side*point_size+overlap),float)
ctr = np.zeros_like(composite_phase)
data_reshaped = preds_intens[1].reshape(tst_side,tst_side,64,64)[:,:,32-int(overlap/2):32+int(overlap/2),
                                                     32-int(overlap/2):32+int(overlap/2)]

for i in range(tst_side):
    for j in range(tst_side):
        composite_phase[point_size*i:point_size*i+overlap, point_size*j:point_size*j+overlap] += data_reshaped[i,j]
        ctr[point_size*i:point_size*i+overlap, point_size*j:point_size*j+overlap] +=1

# %%
plt.matshow(ctr)

# %%
fig, ax = plt.subplots(1,3,figsize=(20,10))

im=ax[0].matshow(np.transpose(preds_intens[1].reshape(tst_side,tst_side,64,64)
                         [:,:,31:34,31:34], (0,2,1,3)).reshape(tst_side*3,tst_side*3))
plt.colorbar(im,ax=ax[0], fraction=0.046, pad=0.04)
#plt.matshow(Y_phi_test.reshape(tst_side,tst_side,64,64)[int(tst_side/,10], vmin=-1, vmax=1.5)

im=ax[1].imshow(ph[tst_strt:,tst_strt:,32,32])
plt.colorbar(im,ax=ax[1], fraction=0.046, pad=0.04)
ax[1].axis('off')
im=ax[2].imshow(composite_phase[int(overlap/2):-int(overlap/2), int(overlap/2):-int(overlap/2)]/ctr[int(overlap/2)
                                                                    :-int(overlap/2), int(overlap/2):-int(overlap/2)])
plt.colorbar(im,ax=ax[2], fraction=0.046, pad=0.04)
ax[2].axis('off')
# Out:
# (-0.5, 179.5, 179.5, -0.5)

# %%
composite_amp = np.zeros((tst_side*point_size+overlap,tst_side*point_size+overlap),float)
ctr = np.zeros_like(composite_amp)
data_reshaped = preds_intens[0].reshape(tst_side,tst_side,64,64)[:,:,32-int(overlap/2):32+int(overlap/2),
                                                     32-int(overlap/2):32+int(overlap/2)]

for i in range(tst_side):
    for j in range(tst_side):
        composite_amp[point_size*i:point_size*i+overlap, point_size*j:point_size*j+overlap] += data_reshaped[i,j]
        ctr[point_size*i:point_size*i+overlap, point_size*j:point_size*j+overlap] +=1

# %%
fig, ax = plt.subplots(1,3,figsize=(20,10))

im=ax[0].matshow(np.transpose(preds_intens[1].reshape(tst_side,tst_side,64,64)
                         [:,:,31:34,31:34], (0,2,1,3)).reshape(tst_side*3,tst_side*3))
plt.colorbar(im,ax=ax[0], fraction=0.046, pad=0.04)
#plt.matshow(Y_phi_test.reshape(tst_side,tst_side,64,64)[int(tst_side/,10], vmin=-1, vmax=1.5)

im=ax[1].imshow(amp[tst_strt:,tst_strt:,32,32])
ax[1].axis('off')
plt.colorbar(im,ax=ax[1], fraction=0.046, pad=0.04, format='%.2f')
im=ax[2].imshow(composite_amp[int(overlap/2):-int(overlap/2), int(overlap/2):-int(overlap/2)]/ctr[int(overlap/2)
                                                                    :-int(overlap/2), int(overlap/2):-int(overlap/2)])
plt.colorbar(im,ax=ax[2], fraction=0.046, pad=0.04, format='%.2f')
ax[2].axis('off')
# Out:
# (-0.5, 179.5, 179.5, -0.5)
