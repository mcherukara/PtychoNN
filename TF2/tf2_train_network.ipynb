# %% [markdown]
# ### Warning: this notebook is for Google Colab.

# %%
# %tensorflow_version 2.x
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
path = '/content/drive/My Drive/Port_PtychoNN_TF2/PtychoNN/TF2/'
import sys
sys.path.append(path)
import keras_helper

# %% [markdown]
# ### Choose GPU settings, import libraries

# %%
#import os
#os.environ["CUDA_VISIBLE_DEVICES"]="0"
#num_GPU = len(os.environ["CUDA_VISIBLE_DEVICES"].split(',')) 

import tensorflow as tf

from tensorflow.keras.layers import Conv2D, MaxPool2D, Dense
from tensorflow.keras import Sequential
from tensorflow.keras import Input
from tensorflow.keras import Model

#config = tf.ConfigProto() 
#config.gpu_options.allow_growth=True 
#session = tf.Session(config=config)
#K.set_session(session)

# %%
#print(os.environ["CUDA_VISIBLE_DEVICES"])
gpus = tf.config.experimental.list_physical_devices('GPU')
print(gpus)
if len(gpus):
  try:
    for gpu in gpus:
      tf.config.experimental.set_memory_growth(gpu, True)
      print("Restricting Memory")
  except RuntimeError as e:
    print(e)
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]
# Restricting Memory

# %%
# !nvidia-smi
# Out:
# Wed Dec 23 23:50:18 2020
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.27.04    Driver Version: 418.67       CUDA Version: 10.1     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   45C    P8    10W /  70W |     10MiB / 15079MiB |      0%      Default |
# |                               |                      |                 ERR! |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
import matplotlib.pyplot as plt
import numpy as np
import glob
from tqdm.notebook import tqdm as tqdm
# Config the matplotlib backend as plotting inline in IPython
# %matplotlib inline

import keras_helper
import importlib
importlib.reload(keras_helper)
from keras_helper import *
from skimage.transform import resize

# %% [markdown]
# ### Some training parameters

# %%
h,w=64,64
nepochs=75
wt_path = 'wts4' #Where to store network weights
batch_size = 32

if (not os.path.isdir(path+wt_path)):
    os.mkdir(wt_path)

# %% [markdown]
# ### Read experimental diffraction data and reconstructed images

# %%
data_diffr = np.load(path+'../data/20191008_39_diff.npz')['arr_0']

# %%
print(data_diffr.shape)
#plt.matshow(np.log10(data_diffr[0,0]))

data_diffr_red = np.zeros((data_diffr.shape[0],data_diffr.shape[1],64,64), float)
for i in tqdm(range(data_diffr.shape[0])):
    for j in range(data_diffr.shape[1]):
        data_diffr_red[i,j] = resize(data_diffr[i,j,32:-32,32:-32],(64,64),preserve_range=True, anti_aliasing=True)
        data_diffr_red[i,j] = np.where(data_diffr_red[i,j]<3,0,data_diffr_red[i,j])
# Out:
# (161, 161, 256, 256)
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:5: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   """
# HBox(children=(FloatProgress(value=0.0, max=161.0), HTML(value='')))

# %%
#amp = np.load('../expt_data/s26_data/20191008_30_10nm_amp.npz')['arr_0']
#ph = np.load('../expt_data/s26_data/20191008_39_10nm.npz')['arr_0']
real_space = np.load(path+'../data/20191008_39_amp_pha_10nm_full.npy')
amp = np.abs(real_space)
ph = np.angle(real_space)
amp.shape
# Out:
# (161, 161, 64, 64)

# %%
fig,ax = plt.subplots(1,2,figsize=(20,10))
ax[0].imshow(amp[:,:,32,32])
ax[1].imshow(ph[:,:,32,32])
# Out:
# findfont: Font family ['Times New Roman'] not found. Falling back to DejaVu Sans.

# %% [markdown]
# ### Split data and then shuffle

# %%
nlines = 100 #How many lines of data to use for training?
nltest = 60 #How many lines for the test set?
tst_strt = amp.shape[0]-nltest #Where to index from
print(tst_strt)
# Out:
# 101

# %%
from sklearn.utils import shuffle
from sklearn.model_selection import train_test_split


X_train = data_diffr_red[:nlines,:].reshape(-1,h,w)[:,:,:,np.newaxis]
X_test = data_diffr_red[tst_strt:,tst_strt:].reshape(-1,h,w)[:,:,:,np.newaxis]
Y_I_train = amp[:nlines,:].reshape(-1,h,w)[:,:,:,np.newaxis]
Y_I_test = amp[tst_strt:,tst_strt:].reshape(-1,h,w)[:,:,:,np.newaxis]
Y_phi_train = ph[:nlines,:].reshape(-1,h,w)[:,:,:,np.newaxis]
Y_phi_test = ph[tst_strt:,tst_strt:].reshape(-1,h,w)[:,:,:,np.newaxis]

ntrain = X_train.shape[0]*X_train.shape[1]
ntest = X_test.shape[0]*X_test.shape[1]

print(X_train.shape, X_test.shape)

X_train, Y_I_train, Y_phi_train = shuffle(X_train, Y_I_train, Y_phi_train, random_state=0)
# Out:
# (16100, 64, 64, 1) (3600, 64, 64, 1)

# %% [markdown]
# ### Save the test data for later use

# %%
#np.save('data/X_test.npy', X_test) #Diffraction data
#np.save('data/Y_I_test.npy', Y_I_test) #Intensity data
#np.save('data/Y_phi_test.npy', Y_phi_test) #Intensity data

# %% [markdown]
# ## Define the network structure

# %%
tf.keras.backend.clear_session()
np.random.seed(123)

files=glob.glob('%s/*' %wt_path)
for file in files:
    os.remove(file)

    
input_img = Input(shape=(h, w, 1)) 

x = Conv_Pool_block(input_img,32,w1=3,w2=3,p1=2,p2=2, padding='same', data_format='channels_last')
x = Conv_Pool_block(x,64,w1=3,w2=3,p1=2,p2=2, padding='same', data_format='channels_last')
x = Conv_Pool_block(x,128,w1=3,w2=3,p1=2,p2=2, padding='same', data_format='channels_last')
#Activations are all ReLu

encoded=x

#Decoding arm 1
x1=Conv_Up_block(encoded,128,w1=3,w2=3,p1=2,p2=2,padding='same', data_format='channels_last')
x1=Conv_Up_block(x1,64,w1=3,w2=3,p1=2,p2=2,padding='same', data_format='channels_last')
x1=Conv_Up_block(x1,32,w1=3,w2=3,p1=2,p2=2,padding='same', data_format='channels_last')

decoded1 = Conv2D(1, (3, 3), padding='same')(x1)


#Decoding arm 2
x2=Conv_Up_block(encoded,128,w1=3,w2=3,p1=2,p2=2,padding='same', data_format='channels_last')
x2=Conv_Up_block(x2,64,w1=3,w2=3,p1=2,p2=2,padding='same', data_format='channels_last')
x2=Conv_Up_block(x2,32,w1=3,w2=3,p1=2,p2=2,padding='same', data_format='channels_last')

decoded2 = Conv2D(1, (3, 3), padding='same')(x2)

#Put together
autoencoder = Model(input_img, [decoded1, decoded2])

#parallel_model = ModelMGPU(autoencoder, gpus=num_GPU)
#parallel_model.compile(optimizer='adam', loss='mean_absolute_error')
autoencoder.compile(optimizer='adam', loss='mean_absolute_error')

print (autoencoder.summary())
#plot_model(autoencoder, to_file='paper_data/str_model.png')
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 64, 64, 1)]  0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 64, 64, 32)   320         input_1[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 64, 64, 32)   9248        conv2d[0][0]
# __________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)    (None, 32, 32, 32)   0           conv2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 32, 32, 64)   18496       max_pooling2d[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 32, 32, 64)   36928       conv2d_2[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 16, 16, 64)   0           conv2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 16, 16, 128)  73856       max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 16, 16, 128)  147584      conv2d_4[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 8, 8, 128)    0           conv2d_5[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 8, 8, 128)    147584      max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 8, 8, 128)    147584      max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 8, 8, 128)    147584      conv2d_6[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 8, 8, 128)    147584      conv2d_13[0][0]
# __________________________________________________________________________________________________
# up_sampling2d (UpSampling2D)    (None, 16, 16, 128)  0           conv2d_7[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_3 (UpSampling2D)  (None, 16, 16, 128)  0           conv2d_14[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 16, 16, 64)   73792       up_sampling2d[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 16, 16, 64)   73792       up_sampling2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 16, 16, 64)   36928       conv2d_8[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 16, 16, 64)   36928       conv2d_15[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_1 (UpSampling2D)  (None, 32, 32, 64)   0           conv2d_9[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_4 (UpSampling2D)  (None, 32, 32, 64)   0           conv2d_16[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 32, 32, 32)   18464       up_sampling2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 32, 32, 32)   18464       up_sampling2d_4[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 32, 32, 32)   9248        conv2d_10[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 32, 32, 32)   9248        conv2d_17[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_2 (UpSampling2D)  (None, 64, 64, 32)   0           conv2d_11[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_5 (UpSampling2D)  (None, 64, 64, 32)   0           conv2d_18[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 64, 64, 1)    289         up_sampling2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 64, 64, 1)    289         up_sampling2d_5[0][0]
# ==================================================================================================
# Total params: 1,154,210
# Trainable params: 1,154,210
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None

# %%
reduce_lr = tf.keras.callbacks.ReduceLROnPlateau(monitor='val_loss', factor=0.5,
                              patience=2, min_lr=0.0001, verbose=1)

checkpoints= tf.keras.callbacks.ModelCheckpoint('%s/weights.{epoch:02d}.hdf5' %wt_path, 
                                            monitor='val_loss', verbose=1, save_best_only=True, 
                                            save_weights_only=False, mode='auto', period=1)

history=autoencoder.fit(X_train, [Y_I_train, Y_phi_train], shuffle=True, batch_size=batch_size, verbose=1, 
                           epochs=nepochs, validation_split = 0.05, callbacks=[checkpoints, reduce_lr])
# Out:
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.
# Epoch 1/75
# 478/478 [==============================] - 20s 25ms/step - loss: 1.0104 - conv2d_12_loss: 0.2241 - conv2d_19_loss: 0.7863 - val_loss: 0.4861 - val_conv2d_12_loss: 0.0072 - val_conv2d_19_loss: 0.4789
#
# Epoch 00001: val_loss improved from inf to 0.48615, saving model to wts4/weights.01.hdf5
# Epoch 2/75
# 478/478 [==============================] - 11s 23ms/step - loss: 0.4747 - conv2d_12_loss: 0.0071 - conv2d_19_loss: 0.4676 - val_loss: 0.4341 - val_conv2d_12_loss: 0.0067 - val_conv2d_19_loss: 0.4274
# 478/478 [==============================] - 11s 23ms/step - loss: 0.4110 - conv2d_12_loss: 0.0068 - conv2d_19_loss: 0.4042 - val_loss: 0.3728 - val_conv2d_12_loss: 0.0065 - val_conv2d_19_loss: 0.3663
#
# Epoch 00003: val_loss improved from 0.43409 to 0.37281, saving model to wts4/weights.03.hdf5
# Epoch 4/75
# 478/478 [==============================] - 11s 23ms/step - loss: 0.3686 - conv2d_12_loss: 0.0065 - conv2d_19_loss: 0.3621 - val_loss: 0.3415 - val_conv2d_12_loss: 0.0063 - val_conv2d_19_loss: 0.3351
#
# Epoch 00004: val_loss improved from 0.37281 to 0.34146, saving model to wts4/weights.04.hdf5
# Epoch 5/75
# 478/478 [==============================] - 11s 23ms/step - loss: 0.3351 - conv2d_12_loss: 0.0063 - conv2d_19_loss: 0.3288 - val_loss: 0.3221 - val_conv2d_12_loss: 0.0062 - val_conv2d_19_loss: 0.3159
#
# Epoch 00005: val_loss improved from 0.34146 to 0.32208, saving model to wts4/weights.05.hdf5
# Epoch 6/75
# 478/478 [==============================] - 11s 24ms/step - loss: 0.3142 - conv2d_12_loss: 0.0062 - conv2d_19_loss: 0.3080 - val_loss: 0.3082 - val_conv2d_12_loss: 0.0061 - val_conv2d_19_loss: 0.3021
#
# Epoch 00006: val_loss improved from 0.32208 to 0.30815, saving model to wts4/weights.06.hdf5
# Epoch 7/75
# 478/478 [==============================] - 12s 24ms/step - loss: 0.2920 - conv2d_12_loss: 0.0061 - conv2d_19_loss: 0.2859 - val_loss: 0.3024 - val_conv2d_12_loss: 0.0060 - val_conv2d_19_loss: 0.2963
#
# Epoch 00007: val_loss improved from 0.30815 to 0.30235, saving model to wts4/weights.07.hdf5
# Epoch 8/75
# 478/478 [==============================] - 12s 24ms/step - loss: 0.2768 - conv2d_12_loss: 0.0060 - conv2d_19_loss: 0.2707 - val_loss: 0.2771 - val_conv2d_12_loss: 0.0060 - val_conv2d_19_loss: 0.2711
#
# Epoch 00008: val_loss improved from 0.30235 to 0.27707, saving model to wts4/weights.08.hdf5
# Epoch 9/75
# 478/478 [==============================] - 12s 25ms/step - loss: 0.2632 - conv2d_12_loss: 0.0060 - conv2d_19_loss: 0.2572 - val_loss: 0.2595 - val_conv2d_12_loss: 0.0059 - val_conv2d_19_loss: 0.2536
#
# Epoch 00009: val_loss improved from 0.27707 to 0.25952, saving model to wts4/weights.09.hdf5
# Epoch 10/75
# 478/478 [==============================] - 12s 25ms/step - loss: 0.2478 - conv2d_12_loss: 0.0059 - conv2d_19_loss: 0.2419 - val_loss: 0.2506 - val_conv2d_12_loss: 0.0059 - val_conv2d_19_loss: 0.2447
#
# Epoch 00010: val_loss improved from 0.25952 to 0.25063, saving model to wts4/weights.10.hdf5
# Epoch 11/75
# 478/478 [==============================] - 12s 24ms/step - loss: 0.2390 - conv2d_12_loss: 0.0058 - conv2d_19_loss: 0.2331 - val_loss: 0.2522 - val_conv2d_12_loss: 0.0058 - val_conv2d_19_loss: 0.2464
#
# Epoch 00011: val_loss did not improve from 0.25063
# Epoch 12/75
# 478/478 [==============================] - 12s 24ms/step - loss: 0.2322 - conv2d_12_loss: 0.0058 - conv2d_19_loss: 0.2264 - val_loss: 0.2425 - val_conv2d_12_loss: 0.0058 - val_conv2d_19_loss: 0.2367
#
# Epoch 00012: val_loss improved from 0.25063 to 0.24252, saving model to wts4/weights.12.hdf5
# Epoch 13/75
# 478/478 [==============================] - 12s 24ms/step - loss: 0.2216 - conv2d_12_loss: 0.0057 - conv2d_19_loss: 0.2159 - val_loss: 0.2348 - val_conv2d_12_loss: 0.0057 - val_conv2d_19_loss: 0.2290
#
# Epoch 00013: val_loss improved from 0.24252 to 0.23478, saving model to wts4/weights.13.hdf5
# Epoch 14/75
# 478/478 [==============================] - 12s 24ms/step - loss: 0.2134 - conv2d_12_loss: 0.0057 - conv2d_19_loss: 0.2077 - val_loss: 0.2332 - val_conv2d_12_loss: 0.0057 - val_conv2d_19_loss: 0.2275
#
# Epoch 00014: val_loss improved from 0.23478 to 0.23320, saving model to wts4/weights.14.hdf5
# Epoch 15/75
# 478/478 [==============================] - 12s 24ms/step - loss: 0.2084 - conv2d_12_loss: 0.0056 - conv2d_19_loss: 0.2028 - val_loss: 0.2169 - val_conv2d_12_loss: 0.0056 - val_conv2d_19_loss: 0.2113
#
# Epoch 00015: val_loss improved from 0.23320 to 0.21689, saving model to wts4/weights.15.hdf5
# Epoch 16/75
# 478/478 [==============================] - 12s 24ms/step - loss: 0.2012 - conv2d_12_loss: 0.0056 - conv2d_19_loss: 0.1956 - val_loss: 0.2149 - val_conv2d_12_loss: 0.0056 - val_conv2d_19_loss: 0.2093
#
# Epoch 00016: val_loss improved from 0.21689 to 0.21495, saving model to wts4/weights.16.hdf5
# Epoch 17/75
# 478/478 [==============================] - 12s 24ms/step - loss: 0.1942 - conv2d_12_loss: 0.0055 - conv2d_19_loss: 0.1887 - val_loss: 0.2122 - val_conv2d_12_loss: 0.0056 - val_conv2d_19_loss: 0.2066
#
# Epoch 00017: val_loss improved from 0.21495 to 0.21216, saving model to wts4/weights.17.hdf5
# Epoch 18/75
# 478/478 [==============================] - 12s 24ms/step - loss: 0.1897 - conv2d_12_loss: 0.0055 - conv2d_19_loss: 0.1842 - val_loss: 0.2053 - val_conv2d_12_loss: 0.0056 - val_conv2d_19_loss: 0.1996
#
# Epoch 00018: val_loss improved from 0.21216 to 0.20526, saving model to wts4/weights.18.hdf5
# Epoch 19/75
# 478/478 [==============================] - 12s 24ms/step - loss: 0.1857 - conv2d_12_loss: 0.0055 - conv2d_19_loss: 0.1802 - val_loss: 0.2080 - val_conv2d_12_loss: 0.0055 - val_conv2d_19_loss: 0.2025
#
# Epoch 00019: val_loss did not improve from 0.20526
# Epoch 20/75
# 478/478 [==============================] - 12s 24ms/step - loss: 0.1818 - conv2d_12_loss: 0.0055 - conv2d_19_loss: 0.1763 - val_loss: 0.1991 - val_conv2d_12_loss: 0.0055 - val_conv2d_19_loss: 0.1935
#
# Epoch 00020: val_loss improved from 0.20526 to 0.19906, saving model to wts4/weights.20.hdf5
# Epoch 21/75
# 478/478 [==============================] - 12s 24ms/step - loss: 0.1772 - conv2d_12_loss: 0.0054 - conv2d_19_loss: 0.1718 - val_loss: 0.2017 - val_conv2d_12_loss: 0.0055 - val_conv2d_19_loss: 0.1962
#
# Epoch 00021: val_loss did not improve from 0.19906
# Epoch 22/75
# 478/478 [==============================] - 12s 24ms/step - loss: 0.1746 - conv2d_12_loss: 0.0054 - conv2d_19_loss: 0.1692 - val_loss: 0.1952 - val_conv2d_12_loss: 0.0055 - val_conv2d_19_loss: 0.1897
#
# Epoch 00022: val_loss improved from 0.19906 to 0.19520, saving model to wts4/weights.22.hdf5
# Epoch 23/75
# 478/478 [==============================] - 12s 24ms/step - loss: 0.1715 - conv2d_12_loss: 0.0053 - conv2d_19_loss: 0.1661 - val_loss: 0.1901 - val_conv2d_12_loss: 0.0055 - val_conv2d_19_loss: 0.1847
#
# Epoch 00023: val_loss improved from 0.19520 to 0.19013, saving model to wts4/weights.23.hdf5
# Epoch 24/75
# 478/478 [==============================] - 12s 24ms/step - loss: 0.1676 - conv2d_12_loss: 0.0053 - conv2d_19_loss: 0.1623 - val_loss: 0.1886 - val_conv2d_12_loss: 0.0054 - val_conv2d_19_loss: 0.1832
#
# Epoch 00024: val_loss improved from 0.19013 to 0.18857, saving model to wts4/weights.24.hdf5
# Epoch 25/75
# 478/478 [==============================] - 12s 24ms/step - loss: 0.1649 - conv2d_12_loss: 0.0053 - conv2d_19_loss: 0.1597 - val_loss: 0.1907 - val_conv2d_12_loss: 0.0054 - val_conv2d_19_loss: 0.1853
#
# Epoch 00025: val_loss did not improve from 0.18857
# Epoch 26/75
# 478/478 [==============================] - 12s 24ms/step - loss: 0.1636 - conv2d_12_loss: 0.0052 - conv2d_19_loss: 0.1583 - val_loss: 0.1834 - val_conv2d_12_loss: 0.0053 - val_conv2d_19_loss: 0.1780
#
# Epoch 00026: val_loss improved from 0.18857 to 0.18336, saving model to wts4/weights.26.hdf5
# Epoch 27/75
# 478/478 [==============================] - 12s 24ms/step - loss: 0.1605 - conv2d_12_loss: 0.0052 - conv2d_19_loss: 0.1553 - val_loss: 0.1813 - val_conv2d_12_loss: 0.0053 - val_conv2d_19_loss: 0.1759
#
# Epoch 00027: val_loss improved from 0.18336 to 0.18126, saving model to wts4/weights.27.hdf5
# Epoch 28/75
# 478/478 [==============================] - 12s 24ms/step - loss: 0.1571 - conv2d_12_loss: 0.0052 - conv2d_19_loss: 0.1520 - val_loss: 0.1810 - val_conv2d_12_loss: 0.0053 - val_conv2d_19_loss: 0.1757
#
# Epoch 00028: val_loss improved from 0.18126 to 0.18100, saving model to wts4/weights.28.hdf5
# Epoch 29/75
# 478/478 [==============================] - 11s 24ms/step - loss: 0.1558 - conv2d_12_loss: 0.0052 - conv2d_19_loss: 0.1507 - val_loss: 0.1782 - val_conv2d_12_loss: 0.0054 - val_conv2d_19_loss: 0.1728
#
# Epoch 00029: val_loss improved from 0.18100 to 0.17816, saving model to wts4/weights.29.hdf5
# Epoch 30/75
# 478/478 [==============================] - 12s 24ms/step - loss: 0.1554 - conv2d_12_loss: 0.0051 - conv2d_19_loss: 0.1503 - val_loss: 0.1779 - val_conv2d_12_loss: 0.0053 - val_conv2d_19_loss: 0.1727
#
# Epoch 00030: val_loss improved from 0.17816 to 0.17794, saving model to wts4/weights.30.hdf5
# Epoch 31/75
# 478/478 [==============================] - 12s 24ms/step - loss: 0.1523 - conv2d_12_loss: 0.0051 - conv2d_19_loss: 0.1472 - val_loss: 0.1770 - val_conv2d_12_loss: 0.0053 - val_conv2d_19_loss: 0.1717
#
# Epoch 00031: val_loss improved from 0.17794 to 0.17699, saving model to wts4/weights.31.hdf5
# Epoch 32/75
# 478/478 [==============================] - 12s 24ms/step - loss: 0.1496 - conv2d_12_loss: 0.0050 - conv2d_19_loss: 0.1446 - val_loss: 0.1741 - val_conv2d_12_loss: 0.0052 - val_conv2d_19_loss: 0.1688
#
# Epoch 00032: val_loss improved from 0.17699 to 0.17406, saving model to wts4/weights.32.hdf5
# Epoch 33/75
# 478/478 [==============================] - 12s 24ms/step - loss: 0.1490 - conv2d_12_loss: 0.0050 - conv2d_19_loss: 0.1439 - val_loss: 0.1743 - val_conv2d_12_loss: 0.0052 - val_conv2d_19_loss: 0.1691
#
# Epoch 00033: val_loss did not improve from 0.17406
# Epoch 34/75
# 478/478 [==============================] - 12s 24ms/step - loss: 0.1469 - conv2d_12_loss: 0.0050 - conv2d_19_loss: 0.1419 - val_loss: 0.1723 - val_conv2d_12_loss: 0.0052 - val_conv2d_19_loss: 0.1671
#
# Epoch 00034: val_loss improved from 0.17406 to 0.17227, saving model to wts4/weights.34.hdf5
# Epoch 35/75
# 478/478 [==============================] - 12s 24ms/step - loss: 0.1463 - conv2d_12_loss: 0.0050 - conv2d_19_loss: 0.1412 - val_loss: 0.1685 - val_conv2d_12_loss: 0.0052 - val_conv2d_19_loss: 0.1633
#
# Epoch 00035: val_loss improved from 0.17227 to 0.16849, saving model to wts4/weights.35.hdf5
# Epoch 36/75
# 478/478 [==============================] - 12s 24ms/step - loss: 0.1451 - conv2d_12_loss: 0.0050 - conv2d_19_loss: 0.1401 - val_loss: 0.1675 - val_conv2d_12_loss: 0.0052 - val_conv2d_19_loss: 0.1624
#
# Epoch 00036: val_loss improved from 0.16849 to 0.16754, saving model to wts4/weights.36.hdf5
# Epoch 37/75
# 478/478 [==============================] - 12s 24ms/step - loss: 0.1431 - conv2d_12_loss: 0.0049 - conv2d_19_loss: 0.1381 - val_loss: 0.1667 - val_conv2d_12_loss: 0.0051 - val_conv2d_19_loss: 0.1616
#
# Epoch 00037: val_loss improved from 0.16754 to 0.16670, saving model to wts4/weights.37.hdf5
# Epoch 38/75
# 478/478 [==============================] - 12s 24ms/step - loss: 0.1412 - conv2d_12_loss: 0.0049 - conv2d_19_loss: 0.1362 - val_loss: 0.1656 - val_conv2d_12_loss: 0.0051 - val_conv2d_19_loss: 0.1605
#
# Epoch 00038: val_loss improved from 0.16670 to 0.16556, saving model to wts4/weights.38.hdf5
# Epoch 39/75
# 478/478 [==============================] - 12s 24ms/step - loss: 0.1407 - conv2d_12_loss: 0.0049 - conv2d_19_loss: 0.1358 - val_loss: 0.1693 - val_conv2d_12_loss: 0.0051 - val_conv2d_19_loss: 0.1642
#
# Epoch 00039: val_loss did not improve from 0.16556
# Epoch 40/75
# 478/478 [==============================] - 12s 24ms/step - loss: 0.1399 - conv2d_12_loss: 0.0049 - conv2d_19_loss: 0.1350 - val_loss: 0.1653 - val_conv2d_12_loss: 0.0051 - val_conv2d_19_loss: 0.1602
#
# Epoch 00040: val_loss improved from 0.16556 to 0.16527, saving model to wts4/weights.40.hdf5
# Epoch 41/75
# 478/478 [==============================] - 12s 24ms/step - loss: 0.1383 - conv2d_12_loss: 0.0049 - conv2d_19_loss: 0.1335 - val_loss: 0.1603 - val_conv2d_12_loss: 0.0051 - val_conv2d_19_loss: 0.1552
#
# Epoch 00041: val_loss improved from 0.16527 to 0.16035, saving model to wts4/weights.41.hdf5
# Epoch 42/75
# 478/478 [==============================] - 12s 24ms/step - loss: 0.1373 - conv2d_12_loss: 0.0048 - conv2d_19_loss: 0.1324 - val_loss: 0.1618 - val_conv2d_12_loss: 0.0051 - val_conv2d_19_loss: 0.1567
#
# Epoch 00042: val_loss did not improve from 0.16035
# Epoch 43/75
# 478/478 [==============================] - 12s 24ms/step - loss: 0.1376 - conv2d_12_loss: 0.0048 - conv2d_19_loss: 0.1328 - val_loss: 0.1646 - val_conv2d_12_loss: 0.0051 - val_conv2d_19_loss: 0.1595
#
# Epoch 00043: val_loss did not improve from 0.16035
#
# Epoch 00043: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# Epoch 44/75
# 478/478 [==============================] - 12s 24ms/step - loss: 0.1217 - conv2d_12_loss: 0.0046 - conv2d_19_loss: 0.1171 - val_loss: 0.1410 - val_conv2d_12_loss: 0.0048 - val_conv2d_19_loss: 0.1362
#
# Epoch 00044: val_loss improved from 0.16035 to 0.14102, saving model to wts4/weights.44.hdf5
# Epoch 45/75
# 478/478 [==============================] - 12s 24ms/step - loss: 0.1096 - conv2d_12_loss: 0.0044 - conv2d_19_loss: 0.1052 - val_loss: 0.1394 - val_conv2d_12_loss: 0.0048 - val_conv2d_19_loss: 0.1346
#
# Epoch 00045: val_loss improved from 0.14102 to 0.13942, saving model to wts4/weights.45.hdf5
# Epoch 46/75
# 478/478 [==============================] - 12s 24ms/step - loss: 0.1069 - conv2d_12_loss: 0.0044 - conv2d_19_loss: 0.1025 - val_loss: 0.1387 - val_conv2d_12_loss: 0.0048 - val_conv2d_19_loss: 0.1339
#
# Epoch 00046: val_loss improved from 0.13942 to 0.13866, saving model to wts4/weights.46.hdf5
# Epoch 47/75
# 478/478 [==============================] - 12s 24ms/step - loss: 0.1054 - conv2d_12_loss: 0.0044 - conv2d_19_loss: 0.1011 - val_loss: 0.1380 - val_conv2d_12_loss: 0.0048 - val_conv2d_19_loss: 0.1332
#
# Epoch 00047: val_loss improved from 0.13866 to 0.13796, saving model to wts4/weights.47.hdf5
# Epoch 48/75
# 478/478 [==============================] - 12s 24ms/step - loss: 0.1040 - conv2d_12_loss: 0.0043 - conv2d_19_loss: 0.0997 - val_loss: 0.1372 - val_conv2d_12_loss: 0.0048 - val_conv2d_19_loss: 0.1324
#
# Epoch 00048: val_loss improved from 0.13796 to 0.13717, saving model to wts4/weights.48.hdf5
# Epoch 49/75
# 478/478 [==============================] - 12s 24ms/step - loss: 0.1033 - conv2d_12_loss: 0.0043 - conv2d_19_loss: 0.0990 - val_loss: 0.1362 - val_conv2d_12_loss: 0.0048 - val_conv2d_19_loss: 0.1314
#
# Epoch 00049: val_loss improved from 0.13717 to 0.13621, saving model to wts4/weights.49.hdf5
# Epoch 50/75
# 478/478 [==============================] - 12s 24ms/step - loss: 0.1025 - conv2d_12_loss: 0.0043 - conv2d_19_loss: 0.0982 - val_loss: 0.1379 - val_conv2d_12_loss: 0.0048 - val_conv2d_19_loss: 0.1331
#
# Epoch 00050: val_loss did not improve from 0.13621
# Epoch 51/75
# 478/478 [==============================] - 12s 24ms/step - loss: 0.1018 - conv2d_12_loss: 0.0043 - conv2d_19_loss: 0.0975 - val_loss: 0.1360 - val_conv2d_12_loss: 0.0048 - val_conv2d_19_loss: 0.1312
#
# Epoch 00051: val_loss improved from 0.13621 to 0.13597, saving model to wts4/weights.51.hdf5
# Epoch 52/75
# 478/478 [==============================] - 12s 24ms/step - loss: 0.1004 - conv2d_12_loss: 0.0043 - conv2d_19_loss: 0.0961 - val_loss: 0.1366 - val_conv2d_12_loss: 0.0047 - val_conv2d_19_loss: 0.1318
#
# Epoch 00052: val_loss did not improve from 0.13597
# Epoch 53/75
# 478/478 [==============================] - 12s 24ms/step - loss: 0.1001 - conv2d_12_loss: 0.0043 - conv2d_19_loss: 0.0958 - val_loss: 0.1355 - val_conv2d_12_loss: 0.0047 - val_conv2d_19_loss: 0.1308
#
# Epoch 00053: val_loss improved from 0.13597 to 0.13552, saving model to wts4/weights.53.hdf5
# Epoch 54/75
# 478/478 [==============================] - 12s 25ms/step - loss: 0.0994 - conv2d_12_loss: 0.0042 - conv2d_19_loss: 0.0952 - val_loss: 0.1341 - val_conv2d_12_loss: 0.0047 - val_conv2d_19_loss: 0.1294
#
# Epoch 00054: val_loss improved from 0.13552 to 0.13413, saving model to wts4/weights.54.hdf5
# Epoch 55/75
# 478/478 [==============================] - 12s 24ms/step - loss: 0.0982 - conv2d_12_loss: 0.0042 - conv2d_19_loss: 0.0939 - val_loss: 0.1339 - val_conv2d_12_loss: 0.0047 - val_conv2d_19_loss: 0.1292
#
# Epoch 00055: val_loss improved from 0.13413 to 0.13395, saving model to wts4/weights.55.hdf5
# Epoch 56/75
# 478/478 [==============================] - 12s 24ms/step - loss: 0.0978 - conv2d_12_loss: 0.0042 - conv2d_19_loss: 0.0936 - val_loss: 0.1339 - val_conv2d_12_loss: 0.0048 - val_conv2d_19_loss: 0.1291
#
# Epoch 00056: val_loss improved from 0.13395 to 0.13389, saving model to wts4/weights.56.hdf5
# Epoch 57/75
# 478/478 [==============================] - 11s 24ms/step - loss: 0.0981 - conv2d_12_loss: 0.0042 - conv2d_19_loss: 0.0939 - val_loss: 0.1335 - val_conv2d_12_loss: 0.0047 - val_conv2d_19_loss: 0.1288
#
# Epoch 00057: val_loss improved from 0.13389 to 0.13350, saving model to wts4/weights.57.hdf5
# Epoch 58/75
# 478/478 [==============================] - 11s 24ms/step - loss: 0.0970 - conv2d_12_loss: 0.0042 - conv2d_19_loss: 0.0928 - val_loss: 0.1335 - val_conv2d_12_loss: 0.0047 - val_conv2d_19_loss: 0.1288
#
# Epoch 00058: val_loss improved from 0.13350 to 0.13347, saving model to wts4/weights.58.hdf5
# Epoch 59/75
# 478/478 [==============================] - 12s 24ms/step - loss: 0.0962 - conv2d_12_loss: 0.0042 - conv2d_19_loss: 0.0921 - val_loss: 0.1340 - val_conv2d_12_loss: 0.0047 - val_conv2d_19_loss: 0.1293
#
# Epoch 00059: val_loss did not improve from 0.13347
#
# Epoch 00059: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# Epoch 60/75
# 478/478 [==============================] - 12s 24ms/step - loss: 0.0897 - conv2d_12_loss: 0.0040 - conv2d_19_loss: 0.0856 - val_loss: 0.1273 - val_conv2d_12_loss: 0.0046 - val_conv2d_19_loss: 0.1227
#
# Epoch 00060: val_loss improved from 0.13347 to 0.12729, saving model to wts4/weights.60.hdf5
# Epoch 61/75
# 478/478 [==============================] - 12s 24ms/step - loss: 0.0844 - conv2d_12_loss: 0.0039 - conv2d_19_loss: 0.0804 - val_loss: 0.1270 - val_conv2d_12_loss: 0.0046 - val_conv2d_19_loss: 0.1224
#
# Epoch 00061: val_loss improved from 0.12729 to 0.12701, saving model to wts4/weights.61.hdf5
# Epoch 62/75
# 478/478 [==============================] - 12s 24ms/step - loss: 0.0830 - conv2d_12_loss: 0.0039 - conv2d_19_loss: 0.0791 - val_loss: 0.1271 - val_conv2d_12_loss: 0.0046 - val_conv2d_19_loss: 0.1224
#
# Epoch 00062: val_loss did not improve from 0.12701
# Epoch 63/75
# 478/478 [==============================] - 12s 24ms/step - loss: 0.0826 - conv2d_12_loss: 0.0039 - conv2d_19_loss: 0.0787 - val_loss: 0.1266 - val_conv2d_12_loss: 0.0047 - val_conv2d_19_loss: 0.1219
#
# Epoch 00063: val_loss improved from 0.12701 to 0.12656, saving model to wts4/weights.63.hdf5
# Epoch 64/75
# 478/478 [==============================] - 12s 24ms/step - loss: 0.0823 - conv2d_12_loss: 0.0039 - conv2d_19_loss: 0.0784 - val_loss: 0.1273 - val_conv2d_12_loss: 0.0046 - val_conv2d_19_loss: 0.1227
#
# Epoch 00064: val_loss did not improve from 0.12656
# Epoch 65/75
# 478/478 [==============================] - 12s 24ms/step - loss: 0.0817 - conv2d_12_loss: 0.0039 - conv2d_19_loss: 0.0779 - val_loss: 0.1266 - val_conv2d_12_loss: 0.0046 - val_conv2d_19_loss: 0.1219
#
# Epoch 00065: val_loss did not improve from 0.12656
#
# Epoch 00065: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# Epoch 66/75
# 478/478 [==============================] - 12s 24ms/step - loss: 0.0789 - conv2d_12_loss: 0.0038 - conv2d_19_loss: 0.0750 - val_loss: 0.1248 - val_conv2d_12_loss: 0.0046 - val_conv2d_19_loss: 0.1202
#
# Epoch 00066: val_loss improved from 0.12656 to 0.12479, saving model to wts4/weights.66.hdf5
# Epoch 67/75
# 478/478 [==============================] - 12s 24ms/step - loss: 0.0766 - conv2d_12_loss: 0.0038 - conv2d_19_loss: 0.0728 - val_loss: 0.1249 - val_conv2d_12_loss: 0.0046 - val_conv2d_19_loss: 0.1203
#
# Epoch 00067: val_loss did not improve from 0.12479
# Epoch 68/75
# 478/478 [==============================] - 12s 24ms/step - loss: 0.0762 - conv2d_12_loss: 0.0038 - conv2d_19_loss: 0.0724 - val_loss: 0.1249 - val_conv2d_12_loss: 0.0046 - val_conv2d_19_loss: 0.1203
#
# Epoch 00068: val_loss did not improve from 0.12479
#
# Epoch 00068: ReduceLROnPlateau reducing learning rate to 0.0001.
# Epoch 69/75
# 478/478 [==============================] - 12s 24ms/step - loss: 0.0753 - conv2d_12_loss: 0.0038 - conv2d_19_loss: 0.0716 - val_loss: 0.1246 - val_conv2d_12_loss: 0.0046 - val_conv2d_19_loss: 0.1200
#
# Epoch 00069: val_loss improved from 0.12479 to 0.12459, saving model to wts4/weights.69.hdf5
# Epoch 70/75
# 478/478 [==============================] - 12s 24ms/step - loss: 0.0747 - conv2d_12_loss: 0.0038 - conv2d_19_loss: 0.0709 - val_loss: 0.1247 - val_conv2d_12_loss: 0.0046 - val_conv2d_19_loss: 0.1201
#
# Epoch 00070: val_loss did not improve from 0.12459
# Epoch 71/75
# 478/478 [==============================] - 12s 24ms/step - loss: 0.0745 - conv2d_12_loss: 0.0037 - conv2d_19_loss: 0.0707 - val_loss: 0.1248 - val_conv2d_12_loss: 0.0046 - val_conv2d_19_loss: 0.1201
#
# Epoch 00071: val_loss did not improve from 0.12459
# Epoch 72/75
# 478/478 [==============================] - 12s 24ms/step - loss: 0.0742 - conv2d_12_loss: 0.0037 - conv2d_19_loss: 0.0704 - val_loss: 0.1246 - val_conv2d_12_loss: 0.0046 - val_conv2d_19_loss: 0.1200
#
# Epoch 00072: val_loss did not improve from 0.12459
# Epoch 73/75
# 478/478 [==============================] - 12s 24ms/step - loss: 0.0740 - conv2d_12_loss: 0.0037 - conv2d_19_loss: 0.0703 - val_loss: 0.1248 - val_conv2d_12_loss: 0.0046 - val_conv2d_19_loss: 0.1202
#
# Epoch 00073: val_loss did not improve from 0.12459
# Epoch 74/75
# 478/478 [==============================] - 12s 24ms/step - loss: 0.0739 - conv2d_12_loss: 0.0037 - conv2d_19_loss: 0.0702 - val_loss: 0.1249 - val_conv2d_12_loss: 0.0046 - val_conv2d_19_loss: 0.1203
#
# Epoch 00074: val_loss did not improve from 0.12459
# Epoch 75/75
# 478/478 [==============================] - 12s 24ms/step - loss: 0.0734 - conv2d_12_loss: 0.0037 - conv2d_19_loss: 0.0697 - val_loss: 0.1248 - val_conv2d_12_loss: 0.0046 - val_conv2d_19_loss: 0.1202
#
# Epoch 00075: val_loss did not improve from 0.12459

# %% [markdown]
# ## Plot metrics of the training

# %%
hist=history
epochs=np.asarray(history.epoch)+1

# %matplotlib inline
import matplotlib
plt.style.use('seaborn-white')
matplotlib.rc('font',family='Times New Roman')
matplotlib.rcParams['font.size'] = 20

f, axarr = plt.subplots(3, sharex=True, figsize=(12, 8))

axarr[0].set(ylabel='Loss')
axarr[0].plot(epochs,hist.history['loss'], 'C3o', label='Total Training')
axarr[0].plot(epochs,hist.history['val_loss'], 'C3-', label='Total Validation')
axarr[0].grid()
axarr[0].legend(loc='center right', bbox_to_anchor=(1.5, 0.5))

axarr[1].set(ylabel='Loss')
axarr[1].plot(epochs,hist.history['conv2d_12_loss'], 'C0o', label='Structure Training')
axarr[1].plot(epochs,hist.history['val_conv2d_12_loss'], 'C0-', label='Structure Validation')
axarr[1].legend(loc='center right', bbox_to_anchor=(1.5, 0.5))
plt.xlabel('Epochs')
plt.tight_layout()
axarr[1].grid()


axarr[2].set(ylabel='Loss')
axarr[2].plot(epochs,hist.history['conv2d_19_loss'], 'C0o', label='Phase Training')
axarr[2].plot(epochs,hist.history['val_conv2d_19_loss'], 'C0-', label='Phase Validation')
axarr[2].legend(loc='center right', bbox_to_anchor=(1.5, 0.5))
plt.tight_layout()
axarr[2].grid()

# %%
np.save(path+'str_history', history.history)

# %% [markdown]
# ### Save the epoch with the lowest validation loss
# (PtychoNN will use these weights)

# %%
val_losses=hist.history['val_loss']
min_epoch=np.argmin(val_losses)+1
print (min_epoch)
np.save(path+'%s/min_epoch' %(wt_path), min_epoch)
# Out:
# 69
