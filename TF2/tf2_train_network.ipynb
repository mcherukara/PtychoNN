# %% [markdown]
# ### Warning: this notebook is for Google Colab.

# %%
# %tensorflow_version 2.x
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# **This path might need changing before running the remaining cells.**

# %%
path = '/content/drive/My Drive/PtychoNN/TF2/'
import sys
sys.path.append(path)
import keras_helper

# %% [markdown]
# ### Choose GPU settings, import libraries

# %%
#import os
#os.environ["CUDA_VISIBLE_DEVICES"]="0"
#num_GPU = len(os.environ["CUDA_VISIBLE_DEVICES"].split(',')) 

import tensorflow as tf

from tensorflow.keras.layers import Conv2D, MaxPool2D, Dense
from tensorflow.keras import Sequential
from tensorflow.keras import Input
from tensorflow.keras import Model

#config = tf.ConfigProto() 
#config.gpu_options.allow_growth=True 
#session = tf.Session(config=config)
#K.set_session(session)

# %%
#print(os.environ["CUDA_VISIBLE_DEVICES"])
gpus = tf.config.experimental.list_physical_devices('GPU')
print(gpus)
if len(gpus):
  try:
    for gpu in gpus:
      tf.config.experimental.set_memory_growth(gpu, True)
      print("Restricting Memory")
  except RuntimeError as e:
    print(e)
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]
# Restricting Memory

# %%
# !nvidia-smi
# Out:
# Sun Jul 18 19:44:52 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 470.42.01    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   39C    P8    10W /  70W |      3MiB / 15109MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
import matplotlib.pyplot as plt
import numpy as np
import glob
from tqdm.notebook import tqdm as tqdm
# Config the matplotlib backend as plotting inline in IPython
# %matplotlib inline

import keras_helper
import importlib
importlib.reload(keras_helper)
from keras_helper import *
from skimage.transform import resize

# %% [markdown]
# ### Some training parameters

# %%
h,w=64,64
nepochs=60
wt_path = 'wts4' #Where to store network weights
batch_size = 32

if (not os.path.isdir(path+wt_path)):
    os.mkdir(wt_path)

# %% [markdown]
# ### Read experimental diffraction data and reconstructed images

# %%
data_diffr = np.load(path+'../data/20191008_39_diff.npz')['arr_0']

# %%
print(data_diffr.shape)
#plt.matshow(np.log10(data_diffr[0,0]))

data_diffr_red = np.zeros((data_diffr.shape[0],data_diffr.shape[1],64,64), float)
for i in tqdm(range(data_diffr.shape[0])):
    for j in range(data_diffr.shape[1]):
        data_diffr_red[i,j] = resize(data_diffr[i,j,32:-32,32:-32],(64,64),preserve_range=True, anti_aliasing=True)
        data_diffr_red[i,j] = np.where(data_diffr_red[i,j]<3,0,data_diffr_red[i,j])
# Out:
# (161, 161, 256, 256)
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   """
# HBox(children=(FloatProgress(value=0.0, max=161.0), HTML(value='')))

# %%
#amp = np.load('../expt_data/s26_data/20191008_30_10nm_amp.npz')['arr_0']
#ph = np.load('../expt_data/s26_data/20191008_39_10nm.npz')['arr_0']
real_space = np.load(path+'../data/20191008_39_amp_pha_10nm_full.npy')
amp = np.abs(real_space)
ph = np.angle(real_space)
amp.shape
# Out:
# (161, 161, 64, 64)

# %%
fig,ax = plt.subplots(1,2,figsize=(20,10))
ax[0].imshow(amp[:,:,32,32])
ax[1].imshow(ph[:,:,32,32])
# Out:
# findfont: Font family ['Times New Roman'] not found. Falling back to DejaVu Sans.

# %% [markdown]
# ### Split data and then shuffle

# %%
nlines = 100 #How many lines of data to use for training?
nltest = 60 #How many lines for the test set?
tst_strt = amp.shape[0]-nltest #Where to index from
print(tst_strt)
# Out:
# 101

# %%
from sklearn.utils import shuffle
from sklearn.model_selection import train_test_split


X_train = data_diffr_red[:nlines,:].reshape(-1,h,w)[:,:,:,np.newaxis]
X_test = data_diffr_red[tst_strt:,tst_strt:].reshape(-1,h,w)[:,:,:,np.newaxis]
Y_I_train = amp[:nlines,:].reshape(-1,h,w)[:,:,:,np.newaxis]
Y_I_test = amp[tst_strt:,tst_strt:].reshape(-1,h,w)[:,:,:,np.newaxis]
Y_phi_train = ph[:nlines,:].reshape(-1,h,w)[:,:,:,np.newaxis]
Y_phi_test = ph[tst_strt:,tst_strt:].reshape(-1,h,w)[:,:,:,np.newaxis]

ntrain = X_train.shape[0]*X_train.shape[1]
ntest = X_test.shape[0]*X_test.shape[1]

print(X_train.shape, X_test.shape)

X_train, Y_I_train, Y_phi_train = shuffle(X_train, Y_I_train, Y_phi_train, random_state=0)
# Out:
# (16100, 64, 64, 1) (3600, 64, 64, 1)

# %% [markdown]
# ### Save the test data for later use

# %%
#np.save('data/X_test.npy', X_test) #Diffraction data
#np.save('data/Y_I_test.npy', Y_I_test) #Intensity data
#np.save('data/Y_phi_test.npy', Y_phi_test) #Intensity data

# %% [markdown]
# ## Define the network structure

# %%
tf.keras.backend.clear_session()
np.random.seed(123)

files=glob.glob('%s/*' %wt_path)
for file in files:
    os.remove(file)

    
input_img = Input(shape=(h, w, 1)) 

x = Conv_Pool_block(input_img,32,w1=3,w2=3,p1=2,p2=2, padding='same', data_format='channels_last')
x = Conv_Pool_block(x,64,w1=3,w2=3,p1=2,p2=2, padding='same', data_format='channels_last')
x = Conv_Pool_block(x,128,w1=3,w2=3,p1=2,p2=2, padding='same', data_format='channels_last')
#Activations are all ReLu

encoded=x

#Decoding arm 1
x1=Conv_Up_block(encoded,128,w1=3,w2=3,p1=2,p2=2,padding='same', data_format='channels_last')
x1=Conv_Up_block(x1,64,w1=3,w2=3,p1=2,p2=2,padding='same', data_format='channels_last')
x1=Conv_Up_block(x1,32,w1=3,w2=3,p1=2,p2=2,padding='same', data_format='channels_last')

decoded1 = Conv2D(1, (3, 3), padding='same')(x1)


#Decoding arm 2
x2=Conv_Up_block(encoded,128,w1=3,w2=3,p1=2,p2=2,padding='same', data_format='channels_last')
x2=Conv_Up_block(x2,64,w1=3,w2=3,p1=2,p2=2,padding='same', data_format='channels_last')
x2=Conv_Up_block(x2,32,w1=3,w2=3,p1=2,p2=2,padding='same', data_format='channels_last')

decoded2 = Conv2D(1, (3, 3), padding='same')(x2)

#Put together
autoencoder = Model(input_img, [decoded1, decoded2])

#parallel_model = ModelMGPU(autoencoder, gpus=num_GPU)
#parallel_model.compile(optimizer='adam', loss='mean_absolute_error')
autoencoder.compile(optimizer='adam', loss='mean_absolute_error')

print (autoencoder.summary())
#plot_model(autoencoder, to_file='paper_data/str_model.png')
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 64, 64, 1)]  0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 64, 64, 32)   320         input_1[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 64, 64, 32)   9248        conv2d[0][0]
# __________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)    (None, 32, 32, 32)   0           conv2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 32, 32, 64)   18496       max_pooling2d[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 32, 32, 64)   36928       conv2d_2[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 16, 16, 64)   0           conv2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 16, 16, 128)  73856       max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 16, 16, 128)  147584      conv2d_4[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 8, 8, 128)    0           conv2d_5[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 8, 8, 128)    147584      max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 8, 8, 128)    147584      max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 8, 8, 128)    147584      conv2d_6[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 8, 8, 128)    147584      conv2d_13[0][0]
# __________________________________________________________________________________________________
# up_sampling2d (UpSampling2D)    (None, 16, 16, 128)  0           conv2d_7[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_3 (UpSampling2D)  (None, 16, 16, 128)  0           conv2d_14[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 16, 16, 64)   73792       up_sampling2d[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 16, 16, 64)   73792       up_sampling2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 16, 16, 64)   36928       conv2d_8[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 16, 16, 64)   36928       conv2d_15[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_1 (UpSampling2D)  (None, 32, 32, 64)   0           conv2d_9[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_4 (UpSampling2D)  (None, 32, 32, 64)   0           conv2d_16[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 32, 32, 32)   18464       up_sampling2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 32, 32, 32)   18464       up_sampling2d_4[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 32, 32, 32)   9248        conv2d_10[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 32, 32, 32)   9248        conv2d_17[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_2 (UpSampling2D)  (None, 64, 64, 32)   0           conv2d_11[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_5 (UpSampling2D)  (None, 64, 64, 32)   0           conv2d_18[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 64, 64, 1)    289         up_sampling2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 64, 64, 1)    289         up_sampling2d_5[0][0]
# ==================================================================================================
# Total params: 1,154,210
# Trainable params: 1,154,210
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None

# %%
reduce_lr = tf.keras.callbacks.ReduceLROnPlateau(monitor='val_loss', factor=0.5,
                              patience=2, min_lr=0.0001, verbose=1)

checkpoints= tf.keras.callbacks.ModelCheckpoint('%s/weights.{epoch:02d}.hdf5' %wt_path, 
                                            monitor='val_loss', verbose=1, save_best_only=True, 
                                            save_weights_only=False, mode='auto', period=1)

history=autoencoder.fit(X_train, [Y_I_train, Y_phi_train], shuffle=True, batch_size=batch_size, verbose=1, 
                           epochs=nepochs, validation_split = 0.05, callbacks=[checkpoints, reduce_lr])
# Out:
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.
# Epoch 1/60
# 478/478 [==============================] - 46s 28ms/step - loss: 0.7453 - conv2d_12_loss: 0.0834 - conv2d_19_loss: 0.6620 - val_loss: 0.4903 - val_conv2d_12_loss: 0.0077 - val_conv2d_19_loss: 0.4825
#
# Epoch 00001: val_loss improved from inf to 0.49025, saving model to wts4/weights.01.hdf5
# Epoch 2/60
# 478/478 [==============================] - 12s 26ms/step - loss: 0.4617 - conv2d_12_loss: 0.0075 - conv2d_19_loss: 0.4542 - val_loss: 0.4391 - val_conv2d_12_loss: 0.0072 - val_conv2d_19_loss: 0.4319
#
# Epoch 00002: val_loss improved from 0.49025 to 0.43914, saving model to wts4/weights.02.hdf5
# Epoch 3/60
# 478/478 [==============================] - 12s 25ms/step - loss: 0.4045 - conv2d_12_loss: 0.0069 - conv2d_19_loss: 0.3976 - val_loss: 0.3782 - val_conv2d_12_loss: 0.0066 - val_conv2d_19_loss: 0.3716
#
# Epoch 00003: val_loss improved from 0.43914 to 0.37825, saving model to wts4/weights.03.hdf5
# Epoch 4/60
# 478/478 [==============================] - 12s 25ms/step - loss: 0.3659 - conv2d_12_loss: 0.0066 - conv2d_19_loss: 0.3594 - val_loss: 0.3567 - val_conv2d_12_loss: 0.0064 - val_conv2d_19_loss: 0.3503
#
# Epoch 00004: val_loss improved from 0.37825 to 0.35674, saving model to wts4/weights.04.hdf5
# Epoch 5/60
# 478/478 [==============================] - 12s 25ms/step - loss: 0.3401 - conv2d_12_loss: 0.0064 - conv2d_19_loss: 0.3337 - val_loss: 0.3256 - val_conv2d_12_loss: 0.0062 - val_conv2d_19_loss: 0.3194
#
# Epoch 00005: val_loss improved from 0.35674 to 0.32564, saving model to wts4/weights.05.hdf5
# Epoch 6/60
# 478/478 [==============================] - 12s 26ms/step - loss: 0.3185 - conv2d_12_loss: 0.0063 - conv2d_19_loss: 0.3122 - val_loss: 0.3377 - val_conv2d_12_loss: 0.0063 - val_conv2d_19_loss: 0.3314
#
# Epoch 00006: val_loss did not improve from 0.32564
# Epoch 7/60
# 478/478 [==============================] - 12s 26ms/step - loss: 0.3027 - conv2d_12_loss: 0.0062 - conv2d_19_loss: 0.2965 - val_loss: 0.2944 - val_conv2d_12_loss: 0.0061 - val_conv2d_19_loss: 0.2883
#
# Epoch 00007: val_loss improved from 0.32564 to 0.29436, saving model to wts4/weights.07.hdf5
# Epoch 8/60
# 478/478 [==============================] - 12s 26ms/step - loss: 0.2877 - conv2d_12_loss: 0.0061 - conv2d_19_loss: 0.2816 - val_loss: 0.2902 - val_conv2d_12_loss: 0.0061 - val_conv2d_19_loss: 0.2841
#
# Epoch 00008: val_loss improved from 0.29436 to 0.29020, saving model to wts4/weights.08.hdf5
# Epoch 9/60
# 478/478 [==============================] - 12s 26ms/step - loss: 0.2754 - conv2d_12_loss: 0.0061 - conv2d_19_loss: 0.2694 - val_loss: 0.2778 - val_conv2d_12_loss: 0.0061 - val_conv2d_19_loss: 0.2717
#
# Epoch 00009: val_loss improved from 0.29020 to 0.27778, saving model to wts4/weights.09.hdf5
# Epoch 10/60
# 478/478 [==============================] - 12s 26ms/step - loss: 0.2631 - conv2d_12_loss: 0.0060 - conv2d_19_loss: 0.2571 - val_loss: 0.2675 - val_conv2d_12_loss: 0.0060 - val_conv2d_19_loss: 0.2615
#
# Epoch 00010: val_loss improved from 0.27778 to 0.26750, saving model to wts4/weights.10.hdf5
# Epoch 11/60
# 478/478 [==============================] - 13s 26ms/step - loss: 0.2553 - conv2d_12_loss: 0.0060 - conv2d_19_loss: 0.2493 - val_loss: 0.2592 - val_conv2d_12_loss: 0.0060 - val_conv2d_19_loss: 0.2532
#
# Epoch 00011: val_loss improved from 0.26750 to 0.25919, saving model to wts4/weights.11.hdf5
# Epoch 12/60
# 478/478 [==============================] - 13s 27ms/step - loss: 0.2449 - conv2d_12_loss: 0.0059 - conv2d_19_loss: 0.2390 - val_loss: 0.2520 - val_conv2d_12_loss: 0.0059 - val_conv2d_19_loss: 0.2461
#
# Epoch 00012: val_loss improved from 0.25919 to 0.25198, saving model to wts4/weights.12.hdf5
# Epoch 13/60
# 478/478 [==============================] - 13s 26ms/step - loss: 0.2339 - conv2d_12_loss: 0.0059 - conv2d_19_loss: 0.2280 - val_loss: 0.2510 - val_conv2d_12_loss: 0.0059 - val_conv2d_19_loss: 0.2451
#
# Epoch 00013: val_loss improved from 0.25198 to 0.25102, saving model to wts4/weights.13.hdf5
# Epoch 14/60
# 478/478 [==============================] - 12s 26ms/step - loss: 0.2295 - conv2d_12_loss: 0.0059 - conv2d_19_loss: 0.2237 - val_loss: 0.2405 - val_conv2d_12_loss: 0.0058 - val_conv2d_19_loss: 0.2347
#
# Epoch 00014: val_loss improved from 0.25102 to 0.24048, saving model to wts4/weights.14.hdf5
# Epoch 15/60
# 478/478 [==============================] - 12s 26ms/step - loss: 0.2249 - conv2d_12_loss: 0.0058 - conv2d_19_loss: 0.2190 - val_loss: 0.2330 - val_conv2d_12_loss: 0.0058 - val_conv2d_19_loss: 0.2272
#
# Epoch 00015: val_loss improved from 0.24048 to 0.23298, saving model to wts4/weights.15.hdf5
# Epoch 16/60
# 478/478 [==============================] - 12s 26ms/step - loss: 0.2177 - conv2d_12_loss: 0.0058 - conv2d_19_loss: 0.2119 - val_loss: 0.2281 - val_conv2d_12_loss: 0.0058 - val_conv2d_19_loss: 0.2223
#
# Epoch 00016: val_loss improved from 0.23298 to 0.22809, saving model to wts4/weights.16.hdf5
# Epoch 17/60
# 478/478 [==============================] - 13s 26ms/step - loss: 0.2116 - conv2d_12_loss: 0.0057 - conv2d_19_loss: 0.2059 - val_loss: 0.2347 - val_conv2d_12_loss: 0.0057 - val_conv2d_19_loss: 0.2290
#
# Epoch 00017: val_loss did not improve from 0.22809
# Epoch 18/60
# 478/478 [==============================] - 13s 27ms/step - loss: 0.2058 - conv2d_12_loss: 0.0057 - conv2d_19_loss: 0.2001 - val_loss: 0.2191 - val_conv2d_12_loss: 0.0057 - val_conv2d_19_loss: 0.2134
#
# Epoch 00018: val_loss improved from 0.22809 to 0.21907, saving model to wts4/weights.18.hdf5
# Epoch 19/60
# 478/478 [==============================] - 12s 26ms/step - loss: 0.1996 - conv2d_12_loss: 0.0056 - conv2d_19_loss: 0.1939 - val_loss: 0.2104 - val_conv2d_12_loss: 0.0056 - val_conv2d_19_loss: 0.2048
#
# Epoch 00019: val_loss improved from 0.21907 to 0.21044, saving model to wts4/weights.19.hdf5
# Epoch 20/60
# 478/478 [==============================] - 12s 26ms/step - loss: 0.1954 - conv2d_12_loss: 0.0056 - conv2d_19_loss: 0.1898 - val_loss: 0.2114 - val_conv2d_12_loss: 0.0056 - val_conv2d_19_loss: 0.2058
#
# Epoch 00020: val_loss did not improve from 0.21044
# Epoch 21/60
# 478/478 [==============================] - 12s 26ms/step - loss: 0.1916 - conv2d_12_loss: 0.0055 - conv2d_19_loss: 0.1861 - val_loss: 0.2077 - val_conv2d_12_loss: 0.0056 - val_conv2d_19_loss: 0.2021
#
# Epoch 00021: val_loss improved from 0.21044 to 0.20768, saving model to wts4/weights.21.hdf5
# Epoch 22/60
# 478/478 [==============================] - 13s 26ms/step - loss: 0.1873 - conv2d_12_loss: 0.0055 - conv2d_19_loss: 0.1818 - val_loss: 0.2117 - val_conv2d_12_loss: 0.0056 - val_conv2d_19_loss: 0.2061
#
# Epoch 00022: val_loss did not improve from 0.20768
# Epoch 23/60
# 478/478 [==============================] - 13s 26ms/step - loss: 0.1834 - conv2d_12_loss: 0.0055 - conv2d_19_loss: 0.1780 - val_loss: 0.1974 - val_conv2d_12_loss: 0.0055 - val_conv2d_19_loss: 0.1919
#
# Epoch 00023: val_loss improved from 0.20768 to 0.19738, saving model to wts4/weights.23.hdf5
# Epoch 24/60
# 478/478 [==============================] - 13s 26ms/step - loss: 0.1797 - conv2d_12_loss: 0.0054 - conv2d_19_loss: 0.1743 - val_loss: 0.1962 - val_conv2d_12_loss: 0.0055 - val_conv2d_19_loss: 0.1907
#
# Epoch 00024: val_loss improved from 0.19738 to 0.19624, saving model to wts4/weights.24.hdf5
# Epoch 25/60
# 478/478 [==============================] - 13s 26ms/step - loss: 0.1775 - conv2d_12_loss: 0.0054 - conv2d_19_loss: 0.1721 - val_loss: 0.1941 - val_conv2d_12_loss: 0.0054 - val_conv2d_19_loss: 0.1887
#
# Epoch 00025: val_loss improved from 0.19624 to 0.19413, saving model to wts4/weights.25.hdf5
# Epoch 26/60
# 478/478 [==============================] - 12s 26ms/step - loss: 0.1739 - conv2d_12_loss: 0.0053 - conv2d_19_loss: 0.1685 - val_loss: 0.1987 - val_conv2d_12_loss: 0.0054 - val_conv2d_19_loss: 0.1933
#
# Epoch 00026: val_loss did not improve from 0.19413
# Epoch 27/60
# 478/478 [==============================] - 12s 26ms/step - loss: 0.1711 - conv2d_12_loss: 0.0053 - conv2d_19_loss: 0.1658 - val_loss: 0.1931 - val_conv2d_12_loss: 0.0054 - val_conv2d_19_loss: 0.1877
#
# Epoch 00027: val_loss improved from 0.19413 to 0.19309, saving model to wts4/weights.27.hdf5
# Epoch 28/60
# 478/478 [==============================] - 12s 26ms/step - loss: 0.1687 - conv2d_12_loss: 0.0053 - conv2d_19_loss: 0.1635 - val_loss: 0.1920 - val_conv2d_12_loss: 0.0053 - val_conv2d_19_loss: 0.1866
#
# Epoch 00028: val_loss improved from 0.19309 to 0.19199, saving model to wts4/weights.28.hdf5
# Epoch 29/60
# 478/478 [==============================] - 13s 26ms/step - loss: 0.1661 - conv2d_12_loss: 0.0052 - conv2d_19_loss: 0.1609 - val_loss: 0.1928 - val_conv2d_12_loss: 0.0054 - val_conv2d_19_loss: 0.1875
#
# Epoch 00029: val_loss did not improve from 0.19199
# Epoch 30/60
# 478/478 [==============================] - 13s 26ms/step - loss: 0.1642 - conv2d_12_loss: 0.0052 - conv2d_19_loss: 0.1590 - val_loss: 0.1835 - val_conv2d_12_loss: 0.0053 - val_conv2d_19_loss: 0.1782
#
# Epoch 00030: val_loss improved from 0.19199 to 0.18346, saving model to wts4/weights.30.hdf5
# Epoch 31/60
# 478/478 [==============================] - 13s 26ms/step - loss: 0.1611 - conv2d_12_loss: 0.0051 - conv2d_19_loss: 0.1560 - val_loss: 0.1879 - val_conv2d_12_loss: 0.0053 - val_conv2d_19_loss: 0.1826
#
# Epoch 00031: val_loss did not improve from 0.18346
# Epoch 32/60
# 478/478 [==============================] - 12s 26ms/step - loss: 0.1590 - conv2d_12_loss: 0.0051 - conv2d_19_loss: 0.1539 - val_loss: 0.1800 - val_conv2d_12_loss: 0.0053 - val_conv2d_19_loss: 0.1747
#
# Epoch 00032: val_loss improved from 0.18346 to 0.18004, saving model to wts4/weights.32.hdf5
# Epoch 33/60
# 478/478 [==============================] - 12s 26ms/step - loss: 0.1561 - conv2d_12_loss: 0.0051 - conv2d_19_loss: 0.1510 - val_loss: 0.1776 - val_conv2d_12_loss: 0.0052 - val_conv2d_19_loss: 0.1724
#
# Epoch 00033: val_loss improved from 0.18004 to 0.17759, saving model to wts4/weights.33.hdf5
# Epoch 34/60
# 478/478 [==============================] - 12s 26ms/step - loss: 0.1551 - conv2d_12_loss: 0.0050 - conv2d_19_loss: 0.1501 - val_loss: 0.1821 - val_conv2d_12_loss: 0.0052 - val_conv2d_19_loss: 0.1768
#
# Epoch 00034: val_loss did not improve from 0.17759
# Epoch 35/60
# 478/478 [==============================] - 13s 26ms/step - loss: 0.1536 - conv2d_12_loss: 0.0050 - conv2d_19_loss: 0.1486 - val_loss: 0.1801 - val_conv2d_12_loss: 0.0052 - val_conv2d_19_loss: 0.1750
#
# Epoch 00035: val_loss did not improve from 0.17759
#
# Epoch 00035: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# Epoch 36/60
# 478/478 [==============================] - 12s 26ms/step - loss: 0.1309 - conv2d_12_loss: 0.0047 - conv2d_19_loss: 0.1262 - val_loss: 0.1525 - val_conv2d_12_loss: 0.0049 - val_conv2d_19_loss: 0.1476
#
# Epoch 00036: val_loss improved from 0.17759 to 0.15249, saving model to wts4/weights.36.hdf5
# Epoch 37/60
# 478/478 [==============================] - 12s 26ms/step - loss: 0.1226 - conv2d_12_loss: 0.0046 - conv2d_19_loss: 0.1180 - val_loss: 0.1544 - val_conv2d_12_loss: 0.0049 - val_conv2d_19_loss: 0.1495
#
# Epoch 00037: val_loss did not improve from 0.15249
# Epoch 38/60
# 478/478 [==============================] - 12s 26ms/step - loss: 0.1200 - conv2d_12_loss: 0.0046 - conv2d_19_loss: 0.1154 - val_loss: 0.1500 - val_conv2d_12_loss: 0.0049 - val_conv2d_19_loss: 0.1451
#
# Epoch 00038: val_loss improved from 0.15249 to 0.14998, saving model to wts4/weights.38.hdf5
# Epoch 39/60
# 478/478 [==============================] - 13s 26ms/step - loss: 0.1177 - conv2d_12_loss: 0.0045 - conv2d_19_loss: 0.1132 - val_loss: 0.1484 - val_conv2d_12_loss: 0.0049 - val_conv2d_19_loss: 0.1435
#
# Epoch 00039: val_loss improved from 0.14998 to 0.14840, saving model to wts4/weights.39.hdf5
# Epoch 40/60
# 478/478 [==============================] - 13s 26ms/step - loss: 0.1162 - conv2d_12_loss: 0.0045 - conv2d_19_loss: 0.1117 - val_loss: 0.1479 - val_conv2d_12_loss: 0.0048 - val_conv2d_19_loss: 0.1430
#
# Epoch 00040: val_loss improved from 0.14840 to 0.14788, saving model to wts4/weights.40.hdf5
# Epoch 41/60
# 478/478 [==============================] - 13s 26ms/step - loss: 0.1149 - conv2d_12_loss: 0.0044 - conv2d_19_loss: 0.1105 - val_loss: 0.1467 - val_conv2d_12_loss: 0.0048 - val_conv2d_19_loss: 0.1419
#
# Epoch 00041: val_loss improved from 0.14788 to 0.14670, saving model to wts4/weights.41.hdf5
# Epoch 42/60
# 478/478 [==============================] - 13s 26ms/step - loss: 0.1140 - conv2d_12_loss: 0.0044 - conv2d_19_loss: 0.1096 - val_loss: 0.1479 - val_conv2d_12_loss: 0.0048 - val_conv2d_19_loss: 0.1431
#
# Epoch 00042: val_loss did not improve from 0.14670
# Epoch 43/60
# 478/478 [==============================] - 12s 26ms/step - loss: 0.1124 - conv2d_12_loss: 0.0044 - conv2d_19_loss: 0.1080 - val_loss: 0.1456 - val_conv2d_12_loss: 0.0048 - val_conv2d_19_loss: 0.1408
#
# Epoch 00043: val_loss improved from 0.14670 to 0.14562, saving model to wts4/weights.43.hdf5
# Epoch 44/60
# 478/478 [==============================] - 13s 26ms/step - loss: 0.1114 - conv2d_12_loss: 0.0043 - conv2d_19_loss: 0.1071 - val_loss: 0.1462 - val_conv2d_12_loss: 0.0048 - val_conv2d_19_loss: 0.1414
#
# Epoch 00044: val_loss did not improve from 0.14562
# Epoch 45/60
# 478/478 [==============================] - 13s 26ms/step - loss: 0.1097 - conv2d_12_loss: 0.0043 - conv2d_19_loss: 0.1054 - val_loss: 0.1450 - val_conv2d_12_loss: 0.0048 - val_conv2d_19_loss: 0.1402
#
# Epoch 00045: val_loss improved from 0.14562 to 0.14498, saving model to wts4/weights.45.hdf5
# Epoch 46/60
# 478/478 [==============================] - 13s 26ms/step - loss: 0.1090 - conv2d_12_loss: 0.0043 - conv2d_19_loss: 0.1047 - val_loss: 0.1437 - val_conv2d_12_loss: 0.0047 - val_conv2d_19_loss: 0.1390
#
# Epoch 00046: val_loss improved from 0.14498 to 0.14374, saving model to wts4/weights.46.hdf5
# Epoch 47/60
# 478/478 [==============================] - 13s 26ms/step - loss: 0.1083 - conv2d_12_loss: 0.0043 - conv2d_19_loss: 0.1041 - val_loss: 0.1443 - val_conv2d_12_loss: 0.0047 - val_conv2d_19_loss: 0.1396
#
# Epoch 00047: val_loss did not improve from 0.14374
# Epoch 48/60
# 478/478 [==============================] - 13s 26ms/step - loss: 0.1071 - conv2d_12_loss: 0.0042 - conv2d_19_loss: 0.1029 - val_loss: 0.1425 - val_conv2d_12_loss: 0.0047 - val_conv2d_19_loss: 0.1378
#
# Epoch 00048: val_loss improved from 0.14374 to 0.14248, saving model to wts4/weights.48.hdf5
# Epoch 49/60
# 478/478 [==============================] - 13s 27ms/step - loss: 0.1066 - conv2d_12_loss: 0.0042 - conv2d_19_loss: 0.1023 - val_loss: 0.1437 - val_conv2d_12_loss: 0.0047 - val_conv2d_19_loss: 0.1390
#
# Epoch 00049: val_loss did not improve from 0.14248
# Epoch 50/60
# 478/478 [==============================] - 13s 26ms/step - loss: 0.1059 - conv2d_12_loss: 0.0042 - conv2d_19_loss: 0.1017 - val_loss: 0.1415 - val_conv2d_12_loss: 0.0047 - val_conv2d_19_loss: 0.1368
#
# Epoch 00050: val_loss improved from 0.14248 to 0.14148, saving model to wts4/weights.50.hdf5
# Epoch 51/60
# 478/478 [==============================] - 12s 26ms/step - loss: 0.1054 - conv2d_12_loss: 0.0042 - conv2d_19_loss: 0.1012 - val_loss: 0.1419 - val_conv2d_12_loss: 0.0047 - val_conv2d_19_loss: 0.1372
#
# Epoch 00051: val_loss did not improve from 0.14148
# Epoch 52/60
# 478/478 [==============================] - 12s 26ms/step - loss: 0.1042 - conv2d_12_loss: 0.0042 - conv2d_19_loss: 0.1000 - val_loss: 0.1403 - val_conv2d_12_loss: 0.0047 - val_conv2d_19_loss: 0.1356
#
# Epoch 00052: val_loss improved from 0.14148 to 0.14025, saving model to wts4/weights.52.hdf5
# Epoch 53/60
# 478/478 [==============================] - 13s 26ms/step - loss: 0.1039 - conv2d_12_loss: 0.0041 - conv2d_19_loss: 0.0997 - val_loss: 0.1392 - val_conv2d_12_loss: 0.0047 - val_conv2d_19_loss: 0.1346
#
# Epoch 00053: val_loss improved from 0.14025 to 0.13924, saving model to wts4/weights.53.hdf5
# Epoch 54/60
# 478/478 [==============================] - 13s 27ms/step - loss: 0.1030 - conv2d_12_loss: 0.0041 - conv2d_19_loss: 0.0989 - val_loss: 0.1387 - val_conv2d_12_loss: 0.0046 - val_conv2d_19_loss: 0.1341
#
# Epoch 00054: val_loss improved from 0.13924 to 0.13875, saving model to wts4/weights.54.hdf5
# Epoch 55/60
# 478/478 [==============================] - 13s 27ms/step - loss: 0.1021 - conv2d_12_loss: 0.0041 - conv2d_19_loss: 0.0980 - val_loss: 0.1396 - val_conv2d_12_loss: 0.0047 - val_conv2d_19_loss: 0.1349
#
# Epoch 00055: val_loss did not improve from 0.13875
# Epoch 56/60
# 478/478 [==============================] - 12s 26ms/step - loss: 0.1022 - conv2d_12_loss: 0.0041 - conv2d_19_loss: 0.0981 - val_loss: 0.1399 - val_conv2d_12_loss: 0.0047 - val_conv2d_19_loss: 0.1352
#
# Epoch 00056: val_loss did not improve from 0.13875
#
# Epoch 00056: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# Epoch 57/60
# 478/478 [==============================] - 12s 26ms/step - loss: 0.0921 - conv2d_12_loss: 0.0039 - conv2d_19_loss: 0.0883 - val_loss: 0.1319 - val_conv2d_12_loss: 0.0045 - val_conv2d_19_loss: 0.1274
#
# Epoch 00057: val_loss improved from 0.13875 to 0.13189, saving model to wts4/weights.57.hdf5
# Epoch 58/60
# 478/478 [==============================] - 13s 26ms/step - loss: 0.0881 - conv2d_12_loss: 0.0038 - conv2d_19_loss: 0.0843 - val_loss: 0.1313 - val_conv2d_12_loss: 0.0046 - val_conv2d_19_loss: 0.1267
#
# Epoch 00058: val_loss improved from 0.13189 to 0.13127, saving model to wts4/weights.58.hdf5
# Epoch 59/60
# 478/478 [==============================] - 13s 27ms/step - loss: 0.0870 - conv2d_12_loss: 0.0038 - conv2d_19_loss: 0.0832 - val_loss: 0.1317 - val_conv2d_12_loss: 0.0045 - val_conv2d_19_loss: 0.1271
#
# Epoch 00059: val_loss did not improve from 0.13127
# Epoch 60/60
# 478/478 [==============================] - 13s 27ms/step - loss: 0.0863 - conv2d_12_loss: 0.0038 - conv2d_19_loss: 0.0825 - val_loss: 0.1313 - val_conv2d_12_loss: 0.0045 - val_conv2d_19_loss: 0.1268
#
# Epoch 00060: val_loss did not improve from 0.13127
#
# Epoch 00060: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.

# %% [markdown]
# ## Plot metrics of the training

# %%
hist=history
epochs=np.asarray(history.epoch)+1

# %matplotlib inline
import matplotlib
plt.style.use('seaborn-white')
matplotlib.rc('font',family='Times New Roman')
matplotlib.rcParams['font.size'] = 20

f, axarr = plt.subplots(3, sharex=True, figsize=(12, 8))

axarr[0].set(ylabel='Loss')
axarr[0].plot(epochs,hist.history['loss'], 'C3o', label='Total Training')
axarr[0].plot(epochs,hist.history['val_loss'], 'C3-', label='Total Validation')
axarr[0].grid()
axarr[0].legend(loc='center right', bbox_to_anchor=(1.5, 0.5))

axarr[1].set(ylabel='Loss')
axarr[1].plot(epochs,hist.history['conv2d_12_loss'], 'C0o', label='Structure Training')
axarr[1].plot(epochs,hist.history['val_conv2d_12_loss'], 'C0-', label='Structure Validation')
axarr[1].legend(loc='center right', bbox_to_anchor=(1.5, 0.5))
plt.xlabel('Epochs')
plt.tight_layout()
axarr[1].grid()


axarr[2].set(ylabel='Loss')
axarr[2].plot(epochs,hist.history['conv2d_19_loss'], 'C0o', label='Phase Training')
axarr[2].plot(epochs,hist.history['val_conv2d_19_loss'], 'C0-', label='Phase Validation')
axarr[2].legend(loc='center right', bbox_to_anchor=(1.5, 0.5))
plt.tight_layout()
axarr[2].grid()

# %%
np.save(path+'str_history', history.history)

# %% [markdown]
# ### Save the epoch with the lowest validation loss
# (PtychoNN will use these weights)

# %%
val_losses=hist.history['val_loss']
min_epoch=np.argmin(val_losses)+1
print (min_epoch)
np.save(path+'%s/min_epoch' %(wt_path), min_epoch)
# Out:
# 58
